# %%
import matplotlib.pyplot as plt
from mysql.connector import Error

# %%
import mysql.connector

CONFIG = {
    "host": "127.0.0.1",   # servidor local
    "port": 3306,          # puerto por defecto
    "user": "",        # tu usuario de MySQL
    "password": "",        # tu contraseña
    "database": "world",   # nombre de tu base de datos
}

# %%
#  Ejercicio 1: Escribe una consulta para mostrar el nombre y la población de todos los países del continente europeo.
QUERY_PAISES_EUROPA = """
SELECT name, population 
FROM country 
WHERE continent = 'Europe'
ORDER BY population DESC;
"""
# Ejercicio 2: Escribe una consulta para mostrar los nombres y las áreas de superficie de los cinco países más grandes del mundo (en términos de área de superficie).
QUERY_PAISES_MAS_GRANDES = """
SELECT name, surfacearea
FROM country
ORDER BY surfacearea DESC
LIMIT 5;
"""
# Ejercicio 3: Escribe una consulta para calcular la población total de todos los países de cada continente y mostrar el resultado junto con el nombre del continente.
QUERY_POBLACION_POR_CONTINENTE = """
SELECT continent, SUM(population) as poblacion_total
FROM country
GROUP BY continent
ORDER BY poblacion_total DESC;
"""

# Ejercicio 4: Escribe una consulta para mostrar el nombre de las ciudades y la población de todos los países de Europa, ordenados por población de la ciudad de manera descendente.
QUERY_CIUDADES_EUROPA = """
SELECT c.name, c.population, co.name as pais
FROM city c
INNER JOIN country co ON c.countrycode = co.code
WHERE co.continent = 'Europe'
ORDER BY c.population DESC;
"""

# Ejercicio 5: Actualiza la población de China (código de país 'CHN') a 1500000000 (1.5 mil millones).
QUERY_ACTUALIZAR_CHINA = """
UPDATE country
SET population = 1500000000
WHERE code = 'CHN';
"""

QUERY_VERIFICAR_CHINA = """
SELECT code, name, population
FROM country
WHERE code = 'CHN';
"""

# Ejercicio 6: Consulta los idiomas oficiales en Sudamérica y gráfica cuántos países comparten cada idioma oficial.
QUERY_IDIOMAS_SUDAMERICA = """
SELECT cl.language, COUNT(DISTINCT cl.countrycode) as cantidad_paises
FROM countrylanguage cl
INNER JOIN country c ON cl.countrycode = c.code
WHERE c.continent = 'South America' AND cl.isofficial = 'T'
GROUP BY cl.language
ORDER BY cantidad_paises DESC;
"""

# Ejercicio 7 Obtén todos los países con esperanza de vida > 75 años y crea un histograma de su distribución.
QUERY_ESPERANZA_VIDA = """ 
SELECT name, LifeExpectancy
FROM country
WHERE LifeExpectancy > 75 
"""

# Ejercicio 8: Calcula la densidad poblacional de todos los países y muestra un gráfico de dispersión entre superficie y población con el color como función del continente.
QUERY_DENSIDAD_POBLACIONAL = """
SELECT 
    name, 
    continent, 
    population, 
    surfacearea, 
    (population / surfacearea) as densidad
FROM country
WHERE population > 0 AND surfacearea > 0;"""

# Ejercicio 9: Visualiza las ciudades con más de 5 millones de habitantes en un gráfico horizontal de barras.
QUERY_CIUDADES_5MILLONES_HABITANTES = """
SELECT name,population
FROM city
WHERE population > 5000000
ORDER BY population ASC;
"""

# Ejercicio 10: Gráfica cuántos idiomas se hablan por continente usando un gráfico de pastel.
QUERY_IDIOMAS_POR_CONTINENTE = """
SELECT c.Continent, COUNT(DISTINCT cl.Language) as cantidad_idiomas
FROM country c
JOIN countrylanguage cl ON c.Code = cl.CountryCode
GROUP BY c.Continent
ORDER BY cantidad_idiomas DESC;
"""


# Esperanza de vida inferior al promedio
QUERY_ESPERANZA_VIDA_BAJO_PROMEDIO = """
SELECT 
    continent,
    COUNT(*) AS paises_afectados,
    ROUND(AVG(lifeexpectancy), 2) AS esperanza_media
FROM country
WHERE lifeexpectancy < (
    SELECT AVG(lifeexpectancy)
    FROM country
    WHERE lifeexpectancy IS NOT NULL
)
AND lifeexpectancy IS NOT NULL
GROUP BY continent
ORDER BY paises_afectados DESC;
"""

# Ejercicio 12, porcentaje de la poblacion total en un pais que viva en la ciudad mas grande
QUERY_PORCENTAJE_CIUDAD_MAS_GRANDE = """
SELECT 
    co.name AS pais,
    c.name AS ciudad_principal,
    ROUND((c.population / co.population) * 100, 2) AS porcentaje
FROM city c
JOIN country co ON c.countrycode = co.code
WHERE c.population = (
    SELECT MAX(population)
    FROM city
    WHERE countrycode = co.code
)
ORDER BY porcentaje DESC
LIMIT 5;
"""

# Ejercicio 13A
# Objetivo:
# Identificar países con alta población donde la diversidad lingüística
# puede suponer una barrera para la educación, la inclusión social
# y la implementación de políticas públicas.
QUERY_PAISES_SIN_IDIOMA_OFICIAL = """
SELECT 
    c.name AS pais,
    c.population,
    COUNT(DISTINCT cl.language) AS total_idiomas
FROM country c
LEFT JOIN countrylanguage cl ON c.code = cl.countrycode
WHERE c.population > 10000000
GROUP BY c.code
HAVING COUNT(CASE WHEN cl.isofficial = 'T' THEN 1 END) = 0
ORDER BY c.population DESC
LIMIT 5;
"""

#Ejercicio 13B
QUERY_PAISES_FRAGMENTACION_LINGUISTICA = """
SELECT 
    c.code,
    c.name,
    c.population,
    c.continent,
    COUNT(DISTINCT cl.language) as total_idiomas,
    COUNT(DISTINCT CASE WHEN cl.isofficial = 'T' THEN cl.language END) as idiomas_oficiales,
    GROUP_CONCAT(DISTINCT CASE WHEN cl.isofficial = 'T' THEN cl.language END SEPARATOR ', ') as idiomas_oficiales_lista
FROM country c
LEFT JOIN countrylanguage cl ON c.code = cl.countrycode
WHERE c.population > 10000000
GROUP BY c.code, c.name, c.population, c.continent
HAVING COUNT(DISTINCT cl.language) >= 5
ORDER BY total_idiomas DESC;
"""

# EJERCICIO 13C – Resumen Ejecutivo
# Consolida los países con mayor riesgo lingüístico en una sola tabla,
# clasificándolos según el tipo de problema:
# - Sin idioma oficial
# - Alta fragmentación lingüística
# Pensado como salida directa para toma de decisiones en ONG o instituciones.
QUERY_PAISES_PROBLEMAS_LINGUISTICOS = """
SELECT 
    c.code,
    c.name,
    c.population,
    c.continent,
    COUNT(DISTINCT cl.language) as total_idiomas,
    COUNT(DISTINCT CASE WHEN cl.isofficial = 'T' THEN cl.language END) as idiomas_oficiales,
    GROUP_CONCAT(DISTINCT CASE WHEN cl.isofficial = 'T' THEN cl.language END SEPARATOR ', ') as idiomas_oficiales_lista,
    CASE 
        WHEN COUNT(DISTINCT CASE WHEN cl.isofficial = 'T' THEN cl.language END) = 0 THEN 'Sin idioma oficial'
        WHEN COUNT(DISTINCT cl.language) >= 5 THEN 'Alta fragmentación'
        ELSE 'Mixto'
    END as problema
FROM country c
LEFT JOIN countrylanguage cl ON c.code = cl.countrycode
WHERE c.population > 10000000
GROUP BY c.code, c.name, c.population, c.continent
HAVING COUNT(DISTINCT CASE WHEN cl.isofficial = 'T' THEN cl.language END) = 0
   OR COUNT(DISTINCT cl.language) >= 5
ORDER BY total_idiomas DESC;
"""


def ejecutar_query(conn, titulo, query):
    """Función auxiliar para ejecutar y mostrar resultados"""
    cursor = None
    try:
        cursor = conn.cursor(dictionary=True)
        cursor.execute(query)
        resultados = cursor.fetchall()

        print("\n" + "="*80)
        print(f"  {titulo}")
        print("="*80)

        if not resultados:
            print("No se encontraron resultados.")
            return

        # Mostrar resultados
        for fila in resultados:
            print(fila)

    except Error as e:
        print(f"ERROR en {titulo}: {e}")
    finally:
        if cursor:
            cursor.close()


def ejecutar_update(conn, titulo, query):
    """Función para ejecutar UPDATE/INSERT/DELETE"""
    cursor = None
    try:
        cursor = conn.cursor()
        cursor.execute(query)
        conn.commit()  # IMPORTANTE: confirmar los cambios

        print("\n" + "="*80)
        print(f"  {titulo}")
        print("="*80)
        print(f"✓ Registros afectados: {cursor.rowcount}")
        print("="*80 + "\n")

    except Error as e:
        print(f"ERROR en {titulo}: {e}")
        conn.rollback()  # Deshacer si hay error
    finally:
        if cursor:
            cursor.close()


def ejecutar_query_con_grafica(conn, titulo, query):
    """Función para ejecutar SELECT, mostrar resultados y hacer gráfica"""
    cursor = None
    try:
        cursor = conn.cursor(dictionary=True)
        cursor.execute(query)
        resultados = cursor.fetchall()

        print("\n" + "="*80)
        print(f"  {titulo}")
        print("="*80)

        if not resultados:
            print("No se encontraron resultados.")
            return

        # Mostrar resultados en consola
        for fila in resultados:
            print(fila)

        # Preparar datos para la gráfica
        idiomas = [fila['language'] for fila in resultados]
        cantidades = [fila['cantidad_paises'] for fila in resultados]

        # Crear la gráfica
        plt.figure(figsize=(10, 6))
        plt.bar(idiomas, cantidades, color='steelblue', edgecolor='black')
        plt.xlabel('Idioma', fontsize=12, fontweight='bold')
        plt.ylabel('Cantidad de Países', fontsize=12, fontweight='bold')
        plt.title(f'{titulo}', fontsize=14, fontweight='bold')
        plt.xticks(rotation=45, ha='right')
        plt.grid(axis='y', alpha=0.3)
        plt.tight_layout()
        plt.show()

    except Error as e:
        print(f"ERROR en {titulo}: {e}")
    finally:
        if cursor:
            cursor.close()


def ejecutar_query_histograma(conn, titulo, query, columna_valor, bins=10):
    """Ejecuta SELECT, imprime tabla resumen y crea histograma profesional"""
    cursor = None
    try:
        cursor = conn.cursor(dictionary=True)
        cursor.execute(query)
        resultados = cursor.fetchall()

        print("\n" + "="*80)
        print(f"  {titulo}")
        print("="*80)

        if not resultados:
            print("No se encontraron resultados.")
            return

        # 1. TABLA RESUMEN PARA LA CONSOLA (Sin diccionarios {} )
        resultados_top = sorted(resultados, key=lambda x: x[columna_valor], reverse=True)
        print(f"Total de países encontrados: {len(resultados)}")
        print(f"{'País':<30} | {'Esperanza de Vida':<15}")
        print("-" * 50)
        for fila in resultados_top[:10]:
            print(f"{fila['name']:<30} | {fila[columna_valor]:>10} años")
        print("...")

        # 2. PREPARACIÓN DEL HISTOGRAMA
        valores = [fila[columna_valor] for fila in resultados if fila[columna_valor] is not None]

        # Configuración de estilo para que combine con tu diapositiva azul
        plt.figure(figsize=(10, 6))
        # Usamos un color celeste que resalte y bordes limpios
        plt.hist(valores, bins=bins, color='#5dade2', edgecolor='white', linewidth=1)
        
        plt.title(f'{titulo}', fontsize=14, fontweight='bold')
        plt.xlabel('Años de Esperanza de Vida', fontsize=12)
        plt.ylabel("Cantidad de Países", fontsize=12)
        plt.grid(axis='y', linestyle='--', alpha=0.3)
        
        # 3. GUARDAR LA IMAGEN (Se guardará en la misma carpeta que tu Jupyter)
        # 'transparent=True' hará que en tu diapositiva azul no se vea el recuadro blanco
        plt.savefig('grafico_ejercicio_7.png', dpi=300, bbox_inches='tight', transparent=True)
        
        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"ERROR en {titulo}: {e}")
    finally:
        if cursor:
            cursor.close()


def ejecutar_query_scatter(conn, titulo, query):
    """Ejecuta SELECT y crea un gráfico de dispersión"""
    cursor = None
    try:
        cursor = conn.cursor(dictionary=True)
        cursor.execute(query)
        resultados = cursor.fetchall()

        if not resultados:
            print("No hay datos para la gráfica.")
            return

        # Extraer datos
        poblacion = [f['population'] for f in resultados]
        area = [f['surfacearea'] for f in resultados]
        continentes = [f['continent'] for f in resultados]
        nombres = [f['name'] for f in resultados]

        # Mapeo de colores por continente
        colores_map = {
            'Asia': 'red', 'Europe': 'blue', 'Africa': 'green',
            'North America': 'orange', 'South America': 'purple',
            'Oceania': 'cyan', 'Antarctica': 'grey'
        }
        colores = [colores_map.get(c, 'black') for c in continentes]

        plt.figure(figsize=(12, 8))

        # Crear scatter plot
        scatter = plt.scatter(area, poblacion, c=colores,
                              alpha=0.6, edgecolors='w', s=100)

        # Configurar escalas logarítmicas (opcional, pero recomendado porque hay países muy pequeños y otros enormes)
        plt.xscale('log')
        plt.yscale('log')

        plt.title(titulo, fontsize=14, fontweight='bold')
        plt.xlabel('Superficie (km²)', fontsize=12)
        plt.ylabel('Población', fontsize=12)

        # Crear una leyenda manual
        import matplotlib.patches as mpatches
        legend_labels = [mpatches.Patch(color=color, label=cont)
                         for cont, color in colores_map.items()]
        plt.legend(handles=legend_labels, title="Continentes",
                   bbox_to_anchor=(1.05, 1), loc='upper left')

        plt.grid(True, which="both", ls="-", alpha=0.2)
        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"ERROR en Scatter Plot: {e}")
    finally:
        if cursor:
            cursor.close()


def ejecutar_query_ciudades_grandes(conn, titulo, query):
    cursor = None
    try:
        cursor = conn.cursor(dictionary=True)
        cursor.execute(query)
        resultados = cursor.fetchall()
        if not resultados:
            print("No se encontraron ciudades con más de 5M.")
            return

        nombres = [f['name'] for f in resultados]
        pob = [f['population'] for f in resultados]

        plt.figure(figsize=(12, 8))
        plt.barh(nombres, pob, color='salmon', edgecolor='black')
        plt.title(titulo, fontweight='bold')
        plt.xlabel('Población')
        # Evita notación científica
        plt.ticklabel_format(style='plain', axis='x')
        plt.grid(axis='x', linestyle='--', alpha=0.6)
        plt.tight_layout()
        plt.show()  # <--- Aquí enseña el gráfico
    except Error as e:
        print(f"Error en Ejercicio 9: {e}")
    finally:
        if cursor:
            cursor.close()

# NUEVA FUNCIÓN EJERCICIO 10 (PASTEL)


def ejecutar_query_pastel(conn, titulo, query):
    cursor = None
    try:
        cursor = conn.cursor(dictionary=True)
        cursor.execute(query)
        resultados = cursor.fetchall()

        if not resultados:
            return

        etiquetas = [f['Continent'] for f in resultados]
        valores = [f['cantidad_idiomas'] for f in resultados]

        total = sum(valores)

        def formato(pct):
            cantidad = int(round(pct * total / 100))
            return f"{cantidad}\n({pct:.1f}%)"

        plt.figure(figsize=(8,8))

        wedges, texts, autotexts = plt.pie(
            valores,
            labels=etiquetas,
            autopct=formato,
            startangle=90,
            colors=plt.cm.Set3.colors,
            wedgeprops={'edgecolor': 'white'},
            textprops={'fontsize': 10}
        )

        plt.title(titulo, fontsize=14, fontweight='bold')
        plt.axis('equal')

        plt.tight_layout()
        plt.show()

    except Error as e:
        print(f"Error en Ej 10: {e}")

    finally:
        if cursor:
            cursor.close()

def ejecutar_query_megaciudades(conn, titulo, query):
    """Ejecuta SELECT para ODS 11, imprime tabla y crea gráfico de barras horizontales"""
    cursor = None
    try:
        cursor = conn.cursor(dictionary=True)
        cursor.execute(query)
        resultados = cursor.fetchall()

        print("\n" + "="*80)
        print(f"  {titulo}")
        print("="*80)

        if not resultados:
            print("No se encontraron resultados.")
            return

        # 1. TABLA RESUMEN PARA CONSOLA
        print(f"{'País':<30} | {'Ciudad Principal':<25} | {'% Población':<12}")
        print("-" * 75)
        for f in resultados:
            print(f"{f['pais']:<30} | {f['ciudad_principal']:<25} | {f['porcentaje']:>10}%")

        # 2. PREPARACIÓN DE DATOS
        paises = [f['pais'] for f in resultados]
        porcentajes = [f['porcentaje'] for f in resultados]

        plt.figure(figsize=(10, 6))
        
        # Color azul profesional para que combine con tu presentación
        plt.barh(paises, porcentajes, color='#1f77b4', edgecolor='black')
        
        # --- AJUSTES PARA ELIMINAR EL EXCESO DEL 100% ---
        # Forzamos el límite a 105 solo para que quepa el texto del % sin que se pase el eje visual
        plt.xlim(0, 105) 
        
        # Quitamos los márgenes internos automáticos de Matplotlib
        plt.gca().margins(y=0.1) 
        
        # Ponemos los ticks (marquitas) solo hasta 100
        plt.xticks([0, 20, 40, 60, 80, 100])

        # Añadimos etiquetas de valor
        for i, v in enumerate(porcentajes):
            plt.text(v + 1, i, f'{v}%', va='center', fontweight='bold', color='black')

        plt.xlabel('% de población en la ciudad principal', fontsize=12)
        plt.title(titulo, fontsize=14, fontweight='bold', pad=20)
        plt.gca().invert_yaxis()
        plt.grid(axis='x', linestyle='--', alpha=0.4)
        
        # 3. GUARDAR IMAGEN
        plt.savefig('grafico_megaciudades_final.png', dpi=300, bbox_inches='tight', transparent=True)
        
        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"Error en {titulo}: {e}")
    finally:
        if cursor:
            cursor.close()

def ejecutar_query_fragmentacion_linguistica_mejorado(conn, titulo, query, top_n=10):
    cursor = None
    try:
        cursor = conn.cursor(dictionary=True)
        cursor.execute(query)
        resultados = cursor.fetchall()
        if not resultados:
            print("No hay datos para mostrar.")
            return

        resultados = resultados[:top_n]

        paises = [f['name'] for f in resultados]  # <--- CORRECCIÓN: f['name'] en vez de f['pais']
        total_idiomas = [f['total_idiomas'] for f in resultados]
        idiomas_oficiales = [f['idiomas_oficiales'] for f in resultados]

        plt.figure(figsize=(12,7))
        bar_width = 0.4
        y = range(len(paises))
        plt.barh(y, total_idiomas, height=bar_width, color='skyblue', label='Total Idiomas', edgecolor='black')
        plt.barh([i + bar_width for i in y], idiomas_oficiales, height=bar_width, color='orange', label='Idiomas Oficiales', edgecolor='black')
        plt.yticks([i + bar_width/2 for i in y], paises)
        plt.xlabel('Cantidad de Idiomas')
        plt.title(titulo, fontsize=14, fontweight='bold')
        plt.legend()
        plt.gca().invert_yaxis()
        plt.grid(axis='x', alpha=0.3)
        plt.tight_layout()
        plt.show()

    except Exception as e:  # <--- Agregado para capturar cualquier error y evitar SyntaxError
        print(f"ERROR en {titulo}: {e}")
    finally:
        if cursor:
            cursor.close()

def ejecutar_query_problemas_linguisticos_mejorado(conn, titulo, query, top_n=10):
    cursor = None
    try:
        cursor = conn.cursor(dictionary=True)
        cursor.execute(query)
        resultados = cursor.fetchall()
        if not resultados:
            print("No hay datos para mostrar.")
            return

        resultados = resultados[:top_n]

        paises = [f['name'] for f in resultados]  # <--- CORRECCIÓN: f['name'] en vez de f['pais']
        problemas = [f['problema'] for f in resultados]
        colores = ['red' if p=='Sin idioma oficial' else 'orange' for p in problemas]

        plt.figure(figsize=(12,7))
        plt.barh(paises, [1]*len(paises), color=colores, edgecolor='black')
        for i, p in enumerate(problemas):
            plt.text(0.5, i, p, ha='center', va='center', color='white', fontweight='bold')
        plt.yticks(paises)
        plt.xticks([])
        plt.title(titulo, fontsize=14, fontweight='bold')
        plt.gca().invert_yaxis()
        plt.tight_layout()
        plt.show()

    except Exception as e:  # <--- Agregado para capturar cualquier error y evitar SyntaxError
        print(f"ERROR en {titulo}: {e}")
    finally:
        if cursor:
            cursor.close()

def main():
    conn = None
    try:
        conn = mysql.connector.connect(**CONFIG)

        # Ejercicio 1: Países de Europa
        ejecutar_query(conn, "Países de Europa",
                       QUERY_PAISES_EUROPA)

        # Ejercicio 2: 5 países más grandes
        ejecutar_query(
            conn, "EJERCICIO 2: Top 5 Países más Grandes (por área)", QUERY_PAISES_MAS_GRANDES)

        # Ejercicio 3: Población por continente
        ejecutar_query(conn, "EJERCICIO 3: Población Total por Continente",
                       QUERY_POBLACION_POR_CONTINENTE)

        # Ejercicio 4: Ciudades de Europa
        ejecutar_query(conn, "EJERCICIO 4: Ciudades de Europa",
                       QUERY_CIUDADES_EUROPA)

        # Ejercicio 5: Actualizar población de China
        ejecutar_update(
            conn, "EJERCICIO 5: Actualizar Población de China", QUERY_ACTUALIZAR_CHINA)

        # Verificar que se actualizó correctamente
        ejecutar_query(
            conn, "Verificación: Población de China Actualizada", QUERY_VERIFICAR_CHINA)

        # Ejercicio 6: Idiomas oficiales en Sudamérica
        ejecutar_query_con_grafica(
            conn, "Idiomas Oficiales en Sudamérica", QUERY_IDIOMAS_SUDAMERICA)

        # Ejercicio 7: Esperanza de vida > 75 años
        ejecutar_query_histograma(
            conn,
            "Esperanza de Vida > 75 años",
            QUERY_ESPERANZA_VIDA,
            columna_valor='LifeExpectancy',
            bins=10
        )

        # Ejercicio 8: Densidad poblacional
        ejecutar_query_scatter(
            conn, "Dispersión Población vs Superficie", QUERY_DENSIDAD_POBLACIONAL)

        # Ejercico 9: Ciudades con mas de 5 millones de habitantes
        ejecutar_query_ciudades_grandes(
            conn, "Ciudades con + 5 Millones de Habitantes", QUERY_CIUDADES_5MILLONES_HABITANTES)

        # EJERCICIO 10 idiomas por continente
        ejecutar_query_pastel(
            conn, "Idiomas por Continente", QUERY_IDIOMAS_POR_CONTINENTE)
        # --------------------------

       # EJERCICIO 11 – Salud
        ejecutar_query(
            conn,"Regiones con Esperanza de Vida Bajo Promedio (ODS 3)",QUERY_ESPERANZA_VIDA_BAJO_PROMEDIO)

       # EJERCICIO 12 – Megaciudades
        ejecutar_query_megaciudades(
            conn,"Países con Mayor Riesgo por Megaciudades (ODS 11)",QUERY_PORCENTAJE_CIUDAD_MAS_GRANDE)

        # EJERCICIO 13A – Idioma oficial
        ejecutar_query(
            conn,"Países sin Idioma Oficial (Alta Población)",QUERY_PAISES_SIN_IDIOMA_OFICIAL)

       # EJERCICIO 13B – Fragmentación lingüística
        ejecutar_query_fragmentacion_linguistica_mejorado(conn, "Top 10 Países con Fragmentación Lingüística", QUERY_PAISES_FRAGMENTACION_LINGUISTICA)

        # Ejercicio 13c: Combinado
        ejecutar_query_problemas_linguisticos_mejorado(conn, "Países con Riesgo Lingüístico (Top 10)", QUERY_PAISES_PROBLEMAS_LINGUISTICOS)

        print("\n" + "="*80)
        print("  ✓ Todas las consultas ejecutadas correctamente")
        print("="*80 + "\n")

    except Error as e:
        print("ERROR de conexión:", e)
    finally:
        if conn and conn.is_connected():
            conn.close()


if __name__ == "__main__":
    main()
# Out:
# ================================================================================
#   Países de Europa
# ================================================================================
# {'name': 'Russian Federation', 'population': 146934000}
# {'name': 'Germany', 'population': 82164700}
# {'name': 'United Kingdom', 'population': 59623400}
# {'name': 'France', 'population': 59225700}
# {'name': 'Italy', 'population': 57680000}
# {'name': 'Ukraine', 'population': 50456000}
# {'name': 'Spain', 'population': 39441700}
# {'name': 'Poland', 'population': 38653600}
# {'name': 'Romania', 'population': 22455500}
# {'name': 'Netherlands', 'population': 15864000}
# {'name': 'Yugoslavia', 'population': 10640000}
# {'name': 'Greece', 'population': 10545700}
# {'name': 'Czech Republic', 'population': 10278100}
# {'name': 'Belgium', 'population': 10239000}
# {'name': 'Belarus', 'population': 10236000}
# {'name': 'Hungary', 'population': 10043200}
# {'name': 'Portugal', 'population': 9997600}
# {'name': 'Sweden', 'population': 8861400}
# {'name': 'Bulgaria', 'population': 8190900}
# {'name': 'Austria', 'population': 8091800}
# {'name': 'Switzerland', 'population': 7160400}
# {'name': 'Slovakia', 'population': 5398700}
# {'name': 'Denmark', 'population': 5330000}
# {'name': 'Finland', 'population': 5171300}
# {'name': 'Norway', 'population': 4478500}
# {'name': 'Croatia', 'population': 4473000}
# {'name': 'Moldova', 'population': 4380000}
# {'name': 'Bosnia and Herzegovina', 'population': 3972000}
# {'name': 'Ireland', 'population': 3775100}
# {'name': 'Lithuania', 'population': 3698500}
# {'name': 'Albania', 'population': 3401200}
# {'name': 'Latvia', 'population': 2424200}
# {'name': 'Macedonia', 'population': 2024000}
# {'name': 'Slovenia', 'population': 1987800}
# {'name': 'Estonia', 'population': 1439200}
# {'name': 'Luxembourg', 'population': 435700}
# {'name': 'Malta', 'population': 380200}
# {'name': 'Iceland', 'population': 279000}
# {'name': 'Andorra', 'population': 78000}
# {'name': 'Faroe Islands', 'population': 43000}
# {'name': 'Monaco', 'population': 34000}
# {'name': 'Liechtenstein', 'population': 32300}
# {'name': 'San Marino', 'population': 27000}
# {'name': 'Gibraltar', 'population': 25000}
# {'name': 'Svalbard and Jan Mayen', 'population': 3200}
# {'name': 'Holy See (Vatican City State)', 'population': 1000}
#
# ================================================================================
#   EJERCICIO 2: Top 5 Países más Grandes (por área)
# ================================================================================
# {'name': 'Russian Federation', 'surfacearea': Decimal('17075400.00')}
# {'name': 'Antarctica', 'surfacearea': Decimal('13120000.00')}
# {'name': 'Canada', 'surfacearea': Decimal('9970610.00')}
# {'name': 'China', 'surfacearea': Decimal('9572900.00')}
# {'name': 'United States', 'surfacearea': Decimal('9363520.00')}
#
# ================================================================================
#   EJERCICIO 3: Población Total por Continente
# ================================================================================
# {'continent': 'Asia', 'poblacion_total': Decimal('3927467700')}
# {'continent': 'Africa', 'poblacion_total': Decimal('784475000')}
# {'continent': 'Europe', 'poblacion_total': Decimal('730074600')}
# {'continent': 'North America', 'poblacion_total': Decimal('482993000')}
# {'continent': 'South America', 'poblacion_total': Decimal('345780000')}
# {'continent': 'Oceania', 'poblacion_total': Decimal('30401150')}
# {'continent': 'Antarctica', 'poblacion_total': Decimal('0')}
#
# ================================================================================
#   EJERCICIO 4: Ciudades de Europa
# ================================================================================
# {'name': 'Moscow', 'population': 8389200, 'pais': 'Russian Federation'}
# {'name': 'London', 'population': 7285000, 'pais': 'United Kingdom'}
# {'name': 'St Petersburg', 'population': 4694000, 'pais': 'Russian Federation'}
# {'name': 'Berlin', 'population': 3386667, 'pais': 'Germany'}
# {'name': 'Madrid', 'population': 2879052, 'pais': 'Spain'}
# {'name': 'Roma', 'population': 2643581, 'pais': 'Italy'}
# {'name': 'Kyiv', 'population': 2624000, 'pais': 'Ukraine'}
# {'name': 'Paris', 'population': 2125246, 'pais': 'France'}
# {'name': 'Bucuresti', 'population': 2016131, 'pais': 'Romania'}
# {'name': 'Budapest', 'population': 1811552, 'pais': 'Hungary'}
# {'name': 'Hamburg', 'population': 1704735, 'pais': 'Germany'}
# {'name': 'Minsk', 'population': 1674000, 'pais': 'Belarus'}
# {'name': 'Warszawa', 'population': 1615369, 'pais': 'Poland'}
# {'name': 'Wien', 'population': 1608144, 'pais': 'Austria'}
# {'name': 'Barcelona', 'population': 1503451, 'pais': 'Spain'}
# {'name': 'Harkova [Harkiv]', 'population': 1500000, 'pais': 'Ukraine'}
# {'name': 'Novosibirsk', 'population': 1398800, 'pais': 'Russian Federation'}
# {'name': 'Nizni Novgorod', 'population': 1357000, 'pais': 'Russian Federation'}
# {'name': 'Milano', 'population': 1300977, 'pais': 'Italy'}
# {'name': 'Jekaterinburg', 'population': 1266300, 'pais': 'Russian Federation'}
# {'name': 'Beograd', 'population': 1204000, 'pais': 'Yugoslavia'}
# {'name': 'Munich [München]', 'population': 1194560, 'pais': 'Germany'}
# {'name': 'Praha', 'population': 1181126, 'pais': 'Czech Republic'}
# {'name': 'Samara', 'population': 1156100, 'pais': 'Russian Federation'}
# {'name': 'Omsk', 'population': 1148900, 'pais': 'Russian Federation'}
# {'name': 'Sofija', 'population': 1122302, 'pais': 'Bulgaria'}
# {'name': 'Dnipropetrovsk', 'population': 1103000, 'pais': 'Ukraine'}
# {'name': 'Kazan', 'population': 1101000, 'pais': 'Russian Federation'}
# {'name': 'Ufa', 'population': 1091200, 'pais': 'Russian Federation'}
# {'name': 'Tšeljabinsk', 'population': 1083200, 'pais': 'Russian Federation'}
# {'name': 'Donetsk', 'population': 1050000, 'pais': 'Ukraine'}
# {'name': 'Birmingham', 'population': 1013000, 'pais': 'United Kingdom'}
# {'name': 'Rostov-na-Donu', 'population': 1012700, 'pais': 'Russian Federation'}
# {'name': 'Odesa', 'population': 1011000, 'pais': 'Ukraine'}
# {'name': 'Perm', 'population': 1009700, 'pais': 'Russian Federation'}
# {'name': 'Napoli', 'population': 1002619, 'pais': 'Italy'}
# {'name': 'Volgograd', 'population': 993400, 'pais': 'Russian Federation'}
# {'name': 'Köln', 'population': 962507, 'pais': 'Germany'}
# {'name': 'Voronez', 'population': 907700, 'pais': 'Russian Federation'}
# {'name': 'Torino', 'population': 903705, 'pais': 'Italy'}
# {'name': 'Krasnojarsk', 'population': 875500, 'pais': 'Russian Federation'}
# {'name': 'Saratov', 'population': 874000, 'pais': 'Russian Federation'}
# {'name': 'Zaporizzja', 'population': 848000, 'pais': 'Ukraine'}
# {'name': 'Lódz', 'population': 800110, 'pais': 'Poland'}
# {'name': 'Marseille', 'population': 798430, 'pais': 'France'}
# {'name': 'Lviv', 'population': 788000, 'pais': 'Ukraine'}
# {'name': 'Athenai', 'population': 772072, 'pais': 'Greece'}
# {'name': 'Riga', 'population': 764328, 'pais': 'Latvia'}
# {'name': 'Stockholm', 'population': 750348, 'pais': 'Sweden'}
# {'name': 'Valencia', 'population': 739412, 'pais': 'Spain'}
# {'name': 'Kraków', 'population': 738150, 'pais': 'Poland'}
# {'name': 'Amsterdam', 'population': 731200, 'pais': 'Netherlands'}
# {'name': 'Toljatti', 'population': 722900, 'pais': 'Russian Federation'}
# {'name': 'Chisinau', 'population': 719900, 'pais': 'Moldova'}
# {'name': 'Zagreb', 'population': 706770, 'pais': 'Croatia'}
# {'name': 'Kryvyi Rig', 'population': 703000, 'pais': 'Ukraine'}
# {'name': 'Sevilla', 'population': 701927, 'pais': 'Spain'}
# {'name': 'Palermo', 'population': 683794, 'pais': 'Italy'}
# {'name': 'Uljanovsk', 'population': 667400, 'pais': 'Russian Federation'}
# {'name': 'Izevsk', 'population': 652800, 'pais': 'Russian Federation'}
# {'name': 'Frankfurt am Main', 'population': 643821, 'pais': 'Germany'}
# {'name': 'Krasnodar', 'population': 639000, 'pais': 'Russian Federation'}
# {'name': 'Wroclaw', 'population': 636765, 'pais': 'Poland'}
# {'name': 'Genova', 'population': 636104, 'pais': 'Italy'}
# {'name': 'Glasgow', 'population': 619680, 'pais': 'United Kingdom'}
# {'name': 'Jaroslavl', 'population': 616700, 'pais': 'Russian Federation'}
# {'name': 'Habarovsk', 'population': 609400, 'pais': 'Russian Federation'}
# {'name': 'Vladivostok', 'population': 606200, 'pais': 'Russian Federation'}
# {'name': 'Zaragoza', 'population': 603367, 'pais': 'Spain'}
# {'name': 'Essen', 'population': 599515, 'pais': 'Germany'}
# {'name': 'Irkutsk', 'population': 593700, 'pais': 'Russian Federation'}
# {'name': 'Rotterdam', 'population': 593321, 'pais': 'Netherlands'}
# {'name': 'Dortmund', 'population': 590213, 'pais': 'Germany'}
# {'name': 'Stuttgart', 'population': 582443, 'pais': 'Germany'}
# {'name': 'Barnaul', 'population': 580100, 'pais': 'Russian Federation'}
# {'name': 'Vilnius', 'population': 577969, 'pais': 'Lithuania'}
# {'name': 'Poznan', 'population': 576899, 'pais': 'Poland'}
# {'name': 'Düsseldorf', 'population': 568855, 'pais': 'Germany'}
# {'name': 'Lisboa', 'population': 563210, 'pais': 'Portugal'}
# {'name': 'Novokuznetsk', 'population': 561600, 'pais': 'Russian Federation'}
# {'name': 'Helsinki [Helsingfors]', 'population': 555474, 'pais': 'Finland'}
# {'name': 'Bremen', 'population': 540330, 'pais': 'Germany'}
# {'name': 'Penza', 'population': 532200, 'pais': 'Russian Federation'}
# {'name': 'Málaga', 'population': 530553, 'pais': 'Spain'}
# {'name': 'Rjazan', 'population': 529900, 'pais': 'Russian Federation'}
# {'name': 'Orenburg', 'population': 523600, 'pais': 'Russian Federation'}
# {'name': 'Lipetsk', 'population': 521000, 'pais': 'Russian Federation'}
# {'name': 'Duisburg', 'population': 519793, 'pais': 'Germany'}
# {'name': 'Hannover', 'population': 514718, 'pais': 'Germany'}
# {'name': 'Nabereznyje Tšelny', 'population': 514700, 'pais': 'Russian Federation'}
# {'name': 'Oslo', 'population': 508726, 'pais': 'Norway'}
# {'name': 'Mykolajiv', 'population': 508000, 'pais': 'Ukraine'}
# {'name': 'Tula', 'population': 506100, 'pais': 'Russian Federation'}
# {'name': 'Tjumen', 'population': 503400, 'pais': 'Russian Federation'}
# {'name': 'København', 'population': 495699, 'pais': 'Denmark'}
# {'name': 'Kemerovo', 'population': 492700, 'pais': 'Russian Federation'}
# {'name': 'Mariupol', 'population': 490000, 'pais': 'Ukraine'}
# {'name': 'Leipzig', 'population': 489532, 'pais': 'Germany'}
# {'name': 'Nürnberg', 'population': 486628, 'pais': 'Germany'}
# {'name': 'Astrahan', 'population': 486100, 'pais': 'Russian Federation'}
# {'name': 'Tomsk', 'population': 482100, 'pais': 'Russian Federation'}
# {'name': 'Dublin', 'population': 481854, 'pais': 'Ireland'}
# {'name': 'Dresden', 'population': 476668, 'pais': 'Germany'}
# {'name': 'Gomel', 'population': 475000, 'pais': 'Belarus'}
# {'name': 'Lugansk', 'population': 469000, 'pais': 'Ukraine'}
# {'name': 'Gothenburg [Göteborg]', 'population': 466990, 'pais': 'Sweden'}
# {'name': 'Kirov', 'population': 466200, 'pais': 'Russian Federation'}
# {'name': 'Liverpool', 'population': 461000, 'pais': 'United Kingdom'}
# {'name': 'Ivanovo', 'population': 459200, 'pais': 'Russian Federation'}
# {'name': 'Tšeboksary', 'population': 459200, 'pais': 'Russian Federation'}
# {'name': 'Gdansk', 'population': 458988, 'pais': 'Poland'}
# {'name': 'Brjansk', 'population': 457400, 'pais': 'Russian Federation'}
# {'name': 'Tver', 'population': 454900, 'pais': 'Russian Federation'}
# {'name': 'Edinburgh', 'population': 450180, 'pais': 'United Kingdom'}
# {'name': 'Bratislava', 'population': 448292, 'pais': 'Slovakia'}
# {'name': 'Antwerpen', 'population': 446525, 'pais': 'Belgium'}
# {'name': 'Lyon', 'population': 445452, 'pais': 'France'}
# {'name': 'Skopje', 'population': 444299, 'pais': 'Macedonia'}
# {'name': 'Kursk', 'population': 443500, 'pais': 'Russian Federation'}
# {'name': 'Haag', 'population': 440900, 'pais': 'Netherlands'}
# {'name': 'Sheffield', 'population': 431607, 'pais': 'United Kingdom'}
# {'name': 'Manchester', 'population': 430000, 'pais': 'United Kingdom'}
# {'name': 'Magnitogorsk', 'population': 427900, 'pais': 'Russian Federation'}
# {'name': 'Kaliningrad', 'population': 424400, 'pais': 'Russian Federation'}
# {'name': 'Leeds', 'population': 424194, 'pais': 'United Kingdom'}
# {'name': 'Szczecin', 'population': 416988, 'pais': 'Poland'}
# {'name': 'Kaunas', 'population': 412639, 'pais': 'Lithuania'}
# {'name': 'Tallinn', 'population': 403981, 'pais': 'Estonia'}
# {'name': 'Bristol', 'population': 402000, 'pais': 'United Kingdom'}
# {'name': 'Bochum', 'population': 392830, 'pais': 'Germany'}
# {'name': 'Vinnytsja', 'population': 391000, 'pais': 'Ukraine'}
# {'name': 'Nizni Tagil', 'population': 390900, 'pais': 'Russian Federation'}
# {'name': 'Toulouse', 'population': 390350, 'pais': 'France'}
# {'name': 'Bydgoszcz', 'population': 386855, 'pais': 'Poland'}
# {'name': 'Makijivka', 'population': 384000, 'pais': 'Ukraine'}
# {'name': 'Thessaloniki', 'population': 383967, 'pais': 'Greece'}
# {'name': 'Brno', 'population': 381862, 'pais': 'Czech Republic'}
# {'name': 'Bologna', 'population': 381161, 'pais': 'Italy'}
# {'name': 'Firenze', 'population': 376662, 'pais': 'Italy'}
# {'name': 'Murmansk', 'population': 376300, 'pais': 'Russian Federation'}
# {'name': 'Ulan-Ude', 'population': 370400, 'pais': 'Russian Federation'}
# {'name': 'Wuppertal', 'population': 368993, 'pais': 'Germany'}
# {'name': 'Kurgan', 'population': 364700, 'pais': 'Russian Federation'}
# {'name': 'Arkangeli', 'population': 361800, 'pais': 'Russian Federation'}
# {'name': 'Sarajevo', 'population': 360000, 'pais': 'Bosnia and Herzegovina'}
# {'name': 'Sotši', 'population': 358600, 'pais': 'Russian Federation'}
# {'name': 'Bilbao', 'population': 357589, 'pais': 'Spain'}
# {'name': 'Lublin', 'population': 356251, 'pais': 'Poland'}
# {'name': 'Mogiljov', 'population': 356000, 'pais': 'Belarus'}
# {'name': 'Las Palmas de Gran Canaria', 'population': 354757, 'pais': 'Spain'}
# {'name': 'Murcia', 'population': 353504, 'pais': 'Spain'}
# {'name': 'Smolensk', 'population': 353400, 'pais': 'Russian Federation'}
# {'name': 'Herson', 'population': 353000, 'pais': 'Ukraine'}
# {'name': 'Iasi', 'population': 348070, 'pais': 'Romania'}
# {'name': 'Sevastopol', 'population': 348000, 'pais': 'Ukraine'}
# {'name': 'Katowice', 'population': 345934, 'pais': 'Poland'}
# {'name': 'Orjol', 'population': 344500, 'pais': 'Russian Federation'}
# {'name': 'Stavropol', 'population': 343300, 'pais': 'Russian Federation'}
# {'name': 'Nice', 'population': 342738, 'pais': 'France'}
# {'name': 'Plovdiv', 'population': 342584, 'pais': 'Bulgaria'}
# {'name': 'Constanta', 'population': 342264, 'pais': 'Romania'}
# {'name': 'Belgorod', 'population': 342000, 'pais': 'Russian Federation'}
# {'name': 'Vitebsk', 'population': 340000, 'pais': 'Belarus'}
# {'name': 'Kaluga', 'population': 339300, 'pais': 'Russian Federation'}
# {'name': 'Simferopol', 'population': 339000, 'pais': 'Ukraine'}
# {'name': 'Catania', 'population': 337862, 'pais': 'Italy'}
# {'name': 'Vladimir', 'population': 337100, 'pais': 'Russian Federation'}
# {'name': 'Zürich', 'population': 336800, 'pais': 'Switzerland'}
# {'name': 'Mahatškala', 'population': 332800, 'pais': 'Russian Federation'}
# {'name': 'Cluj-Napoca', 'population': 332498, 'pais': 'Romania'}
# {'name': 'Bari', 'population': 331848, 'pais': 'Italy'}
# {'name': 'Galati', 'population': 330276, 'pais': 'Romania'}
# {'name': 'Palma de Mallorca', 'population': 326993, 'pais': 'Spain'}
# {'name': 'Tšerepovets', 'population': 324400, 'pais': 'Russian Federation'}
# {'name': 'Timisoara', 'population': 324304, 'pais': 'Romania'}
# {'name': 'Bielefeld', 'population': 321125, 'pais': 'Germany'}
# {'name': 'Cardiff', 'population': 321000, 'pais': 'United Kingdom'}
# {'name': 'Ostrava', 'population': 320041, 'pais': 'Czech Republic'}
# {'name': 'Valladolid', 'population': 319998, 'pais': 'Spain'}
# {'name': 'Saransk', 'population': 314800, 'pais': 'Russian Federation'}
# {'name': 'Brasov', 'population': 314225, 'pais': 'Romania'}
# {'name': 'Craiova', 'population': 313530, 'pais': 'Romania'}
# {'name': 'Pultava [Poltava]', 'population': 313000, 'pais': 'Ukraine'}
# {'name': 'Tšernigiv', 'population': 313000, 'pais': 'Ukraine'}
# {'name': 'Tambov', 'population': 312000, 'pais': 'Russian Federation'}
# {'name': 'Córdoba', 'population': 311708, 'pais': 'Spain'}
# {'name': 'Vladikavkaz', 'population': 310100, 'pais': 'Russian Federation'}
# {'name': 'Tšita', 'population': 309900, 'pais': 'Russian Federation'}
# {'name': 'Tšerkasy', 'population': 309000, 'pais': 'Ukraine'}
# {'name': 'Mannheim', 'population': 307730, 'pais': 'Germany'}
# {'name': 'Coventry', 'population': 304000, 'pais': 'United Kingdom'}
# {'name': 'Vologda', 'population': 302500, 'pais': 'Russian Federation'}
# {'name': 'Grodno', 'population': 302000, 'pais': 'Belarus'}
# {'name': 'Bonn', 'population': 301048, 'pais': 'Germany'}
# {'name': 'Varna', 'population': 299801, 'pais': 'Bulgaria'}
# {'name': 'Veliki Novgorod', 'population': 299500, 'pais': 'Russian Federation'}
# {'name': 'Gorlivka', 'population': 299000, 'pais': 'Ukraine'}
# {'name': 'Zytomyr', 'population': 297000, 'pais': 'Ukraine'}
# {'name': 'Leicester', 'population': 294000, 'pais': 'United Kingdom'}
# {'name': 'Sumy', 'population': 294000, 'pais': 'Ukraine'}
# {'name': 'Komsomolsk-na-Amure', 'population': 291600, 'pais': 'Russian Federation'}
# {'name': 'Bradford', 'population': 289376, 'pais': 'United Kingdom'}
# {'name': 'Kostroma', 'population': 288100, 'pais': 'Russian Federation'}
# {'name': 'Belfast', 'population': 287500, 'pais': 'United Kingdom'}
# {'name': 'Nottingham', 'population': 287000, 'pais': 'United Kingdom'}
# {'name': 'Volzski', 'population': 286900, 'pais': 'Russian Federation'}
# {'name': 'Brest', 'population': 286000, 'pais': 'Belarus'}
# {'name': 'Århus', 'population': 284846, 'pais': 'Denmark'}
# {'name': 'Taganrog', 'population': 284400, 'pais': 'Russian Federation'}
# {'name': 'Bialystok', 'population': 283937, 'pais': 'Poland'}
# {'name': 'Vigo', 'population': 283670, 'pais': 'Spain'}
# {'name': 'Petroskoi', 'population': 282100, 'pais': 'Russian Federation'}
# {'name': 'Gelsenkirchen', 'population': 281979, 'pais': 'Germany'}
# {'name': 'Bratsk', 'population': 277600, 'pais': 'Russian Federation'}
# {'name': 'Venezia', 'population': 277305, 'pais': 'Italy'}
# {'name': 'Karlsruhe', 'population': 277204, 'pais': 'Germany'}
# {'name': 'Dzerzinsk', 'population': 277100, 'pais': 'Russian Federation'}
# {'name': 'Surgut', 'population': 274900, 'pais': 'Russian Federation'}
# {'name': 'Orsk', 'population': 273900, 'pais': 'Russian Federation'}
# {'name': 'Porto', 'population': 273060, 'pais': 'Portugal'}
# {'name': 'Alicante [Alacant]', 'population': 272432, 'pais': 'Spain'}
# {'name': 'Ljubljana', 'population': 270986, 'pais': 'Slovenia'}
# {'name': 'Nantes', 'population': 270251, 'pais': 'France'}
# {'name': 'Tirana', 'population': 270000, 'pais': 'Albania'}
# {'name': 'Dniprodzerzynsk', 'population': 270000, 'pais': 'Ukraine'}
# {'name': 'Wiesbaden', 'population': 268716, 'pais': 'Germany'}
# {'name': 'Gijón', 'population': 267980, 'pais': 'Spain'}
# {'name': 'Sterlitamak', 'population': 265200, 'pais': 'Russian Federation'}
# {'name': 'Kirovograd', 'population': 265000, 'pais': 'Ukraine'}
# {'name': 'Angarsk', 'population': 264700, 'pais': 'Russian Federation'}
# {'name': 'Münster', 'population': 264670, 'pais': 'Germany'}
# {'name': 'Strasbourg', 'population': 264115, 'pais': 'France'}
# {'name': 'Mönchengladbach', 'population': 263697, 'pais': 'Germany'}
# {'name': 'Chemnitz', 'population': 263222, 'pais': 'Germany'}
# {'name': 'Kingston upon Hull', 'population': 262000, 'pais': 'United Kingdom'}
# {'name': 'Hmelnytskyi', 'population': 262000, 'pais': 'Ukraine'}
# {'name': 'Malmö', 'population': 259579, 'pais': 'Sweden'}
# {'name': 'Messina', 'population': 259156, 'pais': 'Italy'}
# {'name': 'Tšernivtsi', 'population': 259000, 'pais': 'Ukraine'}
# {'name': 'Czestochowa', 'population': 257812, 'pais': 'Poland'}
# {'name': 'Verona', 'population': 255268, 'pais': 'Italy'}
# {'name': 'Augsburg', 'population': 254867, 'pais': 'Germany'}
# {'name': 'Halle/Saale', 'population': 254360, 'pais': 'Germany'}
# {'name': 'Gdynia', 'population': 253521, 'pais': 'Poland'}
# {'name': 'Plymouth', 'population': 253000, 'pais': 'United Kingdom'}
# {'name': 'Stoke-on-Trent', 'population': 252000, 'pais': 'United Kingdom'}
# {'name': 'Ploiesti', 'population': 251348, 'pais': 'Romania'}
# {'name': 'Joškar-Ola', 'population': 249200, 'pais': 'Russian Federation'}
# {'name': 'L´Hospitalet de Llobregat', 'population': 247986, 'pais': 'Spain'}
# {'name': 'Braunschweig', 'population': 246322, 'pais': 'Germany'}
# {'name': 'Rivne', 'population': 245000, 'pais': 'Ukraine'}
# {'name': 'Granada', 'population': 244767, 'pais': 'Spain'}
# {'name': 'Sosnowiec', 'population': 244102, 'pais': 'Poland'}
# {'name': 'Aachen', 'population': 243825, 'pais': 'Germany'}
# {'name': 'A Coruña (La Coruña)', 'population': 243402, 'pais': 'Spain'}
# {'name': 'Wolverhampton', 'population': 242000, 'pais': 'United Kingdom'}
# {'name': 'Košice', 'population': 241874, 'pais': 'Slovakia'}
# {'name': 'Krefeld', 'population': 241769, 'pais': 'Germany'}
# {'name': 'Graz', 'population': 240967, 'pais': 'Austria'}
# {'name': 'Rybinsk', 'population': 239600, 'pais': 'Russian Federation'}
# {'name': 'Krementšuk', 'population': 239000, 'pais': 'Ukraine'}
# {'name': 'Prokopjevsk', 'population': 237300, 'pais': 'Russian Federation'}
# {'name': 'Ivano-Frankivsk', 'population': 237000, 'pais': 'Ukraine'}
# {'name': 'Derby', 'population': 236000, 'pais': 'United Kingdom'}
# {'name': 'Ternopil', 'population': 236000, 'pais': 'Ukraine'}
# {'name': 'Magdeburg', 'population': 235073, 'pais': 'Germany'}
# {'name': 'Utrecht', 'population': 234323, 'pais': 'Netherlands'}
# {'name': 'Niznevartovsk', 'population': 233900, 'pais': 'Russian Federation'}
# {'name': 'Kiel', 'population': 233795, 'pais': 'Germany'}
# {'name': 'Braila', 'population': 233756, 'pais': 'Romania'}
# {'name': 'Naltšik', 'population': 233400, 'pais': 'Russian Federation'}
# {'name': 'Radom', 'population': 232262, 'pais': 'Poland'}
# {'name': 'Bergen', 'population': 230948, 'pais': 'Norway'}
# {'name': 'Swansea', 'population': 230000, 'pais': 'United Kingdom'}
# {'name': 'Syktyvkar', 'population': 229700, 'pais': 'Russian Federation'}
# {'name': 'Severodvinsk', 'population': 229300, 'pais': 'Russian Federation'}
# {'name': 'Montpellier', 'population': 225392, 'pais': 'France'}
# {'name': 'Bijsk', 'population': 225000, 'pais': 'Russian Federation'}
# {'name': 'Gent', 'population': 224180, 'pais': 'Belgium'}
# {'name': 'Niznekamsk', 'population': 223400, 'pais': 'Russian Federation'}
# {'name': 'Oberhausen', 'population': 222349, 'pais': 'Germany'}
# {'name': 'Oradea', 'population': 222239, 'pais': 'Romania'}
# {'name': 'Blagoveštšensk', 'population': 222000, 'pais': 'Russian Federation'}
# {'name': 'Šahty', 'population': 221800, 'pais': 'Russian Federation'}
# {'name': 'Bobruisk', 'population': 221000, 'pais': 'Belarus'}
# {'name': 'Vitoria-Gasteiz', 'population': 217154, 'pais': 'Spain'}
# {'name': 'Lutsk', 'population': 217000, 'pais': 'Ukraine'}
# {'name': 'Trieste', 'population': 216459, 'pais': 'Italy'}
# {'name': 'Southampton', 'population': 216000, 'pais': 'United Kingdom'}
# {'name': 'Bordeaux', 'population': 215363, 'pais': 'France'}
# {'name': 'Bila Tserkva', 'population': 215000, 'pais': 'Ukraine'}
# {'name': 'Staryi Oskol', 'population': 213800, 'pais': 'Russian Federation'}
# {'name': 'Lübeck', 'population': 213326, 'pais': 'Germany'}
# {'name': 'Espoo', 'population': 213271, 'pais': 'Finland'}
# {'name': 'Aberdeen', 'population': 213070, 'pais': 'United Kingdom'}
# {'name': 'Santa Cruz de Tenerife', 'population': 213050, 'pais': 'Spain'}
# {'name': 'Kielce', 'population': 212383, 'pais': 'Poland'}
# {'name': 'Gliwice', 'population': 212164, 'pais': 'Poland'}
# {'name': 'Padova', 'population': 211391, 'pais': 'Italy'}
# {'name': 'Badalona', 'population': 209635, 'pais': 'Spain'}
# {'name': 'Bacau', 'population': 209235, 'pais': 'Romania'}
# {'name': 'Taranto', 'population': 208214, 'pais': 'Italy'}
# {'name': 'Zelenograd', 'population': 207100, 'pais': 'Russian Federation'}
# {'name': 'Rennes', 'population': 206229, 'pais': 'France'}
# {'name': 'Torun', 'population': 206158, 'pais': 'Poland'}
# {'name': 'Balakovo', 'population': 206000, 'pais': 'Russian Federation'}
# {'name': 'Bytom', 'population': 205560, 'pais': 'Poland'}
# {'name': 'Hagen', 'population': 205201, 'pais': 'Germany'}
# {'name': 'Debrecen', 'population': 203648, 'pais': 'Hungary'}
# {'name': 'Novorossijsk', 'population': 203300, 'pais': 'Russian Federation'}
# {'name': 'Rostock', 'population': 203279, 'pais': 'Germany'}
# {'name': 'Freiburg im Breisgau', 'population': 202455, 'pais': 'Germany'}
# {'name': 'Klaipeda', 'population': 202451, 'pais': 'Lithuania'}
# {'name': 'Eindhoven', 'population': 201843, 'pais': 'Netherlands'}
# {'name': 'Pihkova', 'population': 201500, 'pais': 'Russian Federation'}
# {'name': 'Erfurt', 'population': 201267, 'pais': 'Germany'}
# {'name': 'Charleroi', 'population': 200827, 'pais': 'Belgium'}
# {'name': 'Oviedo', 'population': 200453, 'pais': 'Spain'}
# {'name': 'Zabrze', 'population': 200177, 'pais': 'Poland'}
# {'name': 'Zlatoust', 'population': 196900, 'pais': 'Russian Federation'}
# {'name': 'Kassel', 'population': 196211, 'pais': 'Germany'}
# {'name': 'Northampton', 'population': 196000, 'pais': 'United Kingdom'}
# {'name': 'Tampere', 'population': 195468, 'pais': 'Finland'}
# {'name': 'Jakutsk', 'population': 195400, 'pais': 'Russian Federation'}
# {'name': 'Móstoles', 'population': 195351, 'pais': 'Spain'}
# {'name': 'Burgas', 'population': 195255, 'pais': 'Bulgaria'}
# {'name': 'Tiraspol', 'population': 194300, 'pais': 'Moldova'}
# {'name': 'Podolsk', 'population': 194300, 'pais': 'Russian Federation'}
# {'name': 'Petropavlovsk-Kamtšatski', 'population': 194100, 'pais': 'Russian Federation'}
# {'name': 'Tilburg', 'population': 193238, 'pais': 'Netherlands'}
# {'name': 'Elche [Elx]', 'population': 193174, 'pais': 'Spain'}
# {'name': 'Dudley', 'population': 192171, 'pais': 'United Kingdom'}
# {'name': 'Brescia', 'population': 191317, 'pais': 'Italy'}
# {'name': 'Le Havre', 'population': 190905, 'pais': 'France'}
# {'name': 'Kamensk-Uralski', 'population': 190600, 'pais': 'Russian Federation'}
# {'name': 'Portsmouth', 'population': 190000, 'pais': 'United Kingdom'}
# {'name': 'Uppsala', 'population': 189569, 'pais': 'Sweden'}
# {'name': 'Split', 'population': 189388, 'pais': 'Croatia'}
# {'name': 'Newcastle upon Tyne', 'population': 189150, 'pais': 'United Kingdom'}
# {'name': 'Engels', 'population': 189000, 'pais': 'Russian Federation'}
# {'name': 'Linz', 'population': 188022, 'pais': 'Austria'}
# {'name': 'Reims', 'population': 187206, 'pais': 'France'}
# {'name': 'Pitesti', 'population': 187170, 'pais': 'Romania'}
# {'name': 'Syzran', 'population': 186900, 'pais': 'Russian Federation'}
# {'name': 'Grozny', 'population': 186000, 'pais': 'Russian Federation'}
# {'name': 'Kramatorsk', 'population': 186000, 'pais': 'Ukraine'}
# {'name': 'Liège', 'population': 185639, 'pais': 'Belgium'}
# {'name': 'Sabadell', 'population': 184859, 'pais': 'Spain'}
# {'name': 'Lille', 'population': 184657, 'pais': 'France'}
# {'name': 'Arad', 'population': 184408, 'pais': 'Romania'}
# {'name': 'Novotšerkassk', 'population': 184400, 'pais': 'Russian Federation'}
# {'name': 'Santander', 'population': 184165, 'pais': 'Spain'}
# {'name': 'Odense', 'population': 183912, 'pais': 'Denmark'}
# {'name': 'Saarbrücken', 'population': 183836, 'pais': 'Germany'}
# {'name': 'Sunderland', 'population': 183310, 'pais': 'United Kingdom'}
# {'name': 'Mainz', 'population': 183134, 'pais': 'Germany'}
# {'name': 'Luton', 'population': 183000, 'pais': 'United Kingdom'}
# {'name': 'Pireus', 'population': 182671, 'pais': 'Greece'}
# {'name': 'Jerez de la Frontera', 'population': 182660, 'pais': 'Spain'}
# {'name': 'Berezniki', 'population': 181900, 'pais': 'Russian Federation'}
# {'name': 'Hamm', 'population': 181804, 'pais': 'Germany'}
# {'name': 'Pamplona [Iruña]', 'population': 180483, 'pais': 'Spain'}
# {'name': 'Bielsko-Biala', 'population': 180307, 'pais': 'Poland'}
# {'name': 'St-Étienne', 'population': 180210, 'pais': 'France'}
# {'name': 'Swindon', 'population': 180000, 'pais': 'United Kingdom'}
# {'name': 'Novi Sad', 'population': 179626, 'pais': 'Yugoslavia'}
# {'name': 'Reggio di Calabria', 'population': 179617, 'pais': 'Italy'}
# {'name': 'Donostia-San Sebastián', 'population': 179208, 'pais': 'Spain'}
# {'name': 'Juzno-Sahalinsk', 'population': 179200, 'pais': 'Russian Federation'}
# {'name': 'Vantaa', 'population': 178471, 'pais': 'Finland'}
# {'name': 'Volgodonsk', 'population': 178200, 'pais': 'Russian Federation'}
# {'name': 'Cartagena', 'population': 177709, 'pais': 'Spain'}
# {'name': 'Modena', 'population': 176022, 'pais': 'Italy'}
# {'name': 'Southend-on-Sea', 'population': 176000, 'pais': 'United Kingdom'}
# {'name': 'Herne', 'population': 175661, 'pais': 'Germany'}
# {'name': 'Niš', 'population': 175391, 'pais': 'Yugoslavia'}
# {'name': 'Walsall', 'population': 174739, 'pais': 'United Kingdom'}
# {'name': 'Mülheim an der Ruhr', 'population': 173895, 'pais': 'Germany'}
# {'name': 'Geneve', 'population': 173500, 'pais': 'Switzerland'}
# {'name': 'Leganés', 'population': 173163, 'pais': 'Spain'}
# {'name': 'Groningen', 'population': 172701, 'pais': 'Netherlands'}
# {'name': 'Turku [Åbo]', 'population': 172561, 'pais': 'Finland'}
# {'name': 'Prato', 'population': 172473, 'pais': 'Italy'}
# {'name': 'Miskolc', 'population': 172357, 'pais': 'Hungary'}
# {'name': 'Fuenlabrada', 'population': 171173, 'pais': 'Spain'}
# {'name': 'Olsztyn', 'population': 170904, 'pais': 'Poland'}
# {'name': 'Sibiu', 'population': 169611, 'pais': 'Romania'}
# {'name': 'Abakan', 'population': 169200, 'pais': 'Russian Federation'}
# {'name': 'Almería', 'population': 169027, 'pais': 'Spain'}
# {'name': 'Melitopol', 'population': 169000, 'pais': 'Ukraine'}
# {'name': 'Parma', 'population': 168717, 'pais': 'Italy'}
# {'name': 'Terrassa', 'population': 168695, 'pais': 'Spain'}
# {'name': 'Rijeka', 'population': 167964, 'pais': 'Croatia'}
# {'name': 'Maikop', 'population': 167300, 'pais': 'Russian Federation'}
# {'name': 'Baranovitši', 'population': 167000, 'pais': 'Belarus'}
# {'name': 'Plzen', 'population': 166759, 'pais': 'Czech Republic'}
# {'name': 'Basel', 'population': 166700, 'pais': 'Switzerland'}
# {'name': 'Ruse', 'population': 166467, 'pais': 'Bulgaria'}
# {'name': 'Miass', 'population': 166200, 'pais': 'Russian Federation'}
# {'name': 'Cagliari', 'population': 165926, 'pais': 'Italy'}
# {'name': 'Solingen', 'population': 165583, 'pais': 'Germany'}
# {'name': 'Târgu Mures', 'population': 165153, 'pais': 'Romania'}
# {'name': 'Armavir', 'population': 164900, 'pais': 'Russian Federation'}
# {'name': 'Osnabrück', 'population': 164539, 'pais': 'Germany'}
# {'name': 'Alcalá de Henares', 'population': 164463, 'pais': 'Spain'}
# {'name': 'Ljubertsy', 'population': 163900, 'pais': 'Russian Federation'}
# {'name': 'Ludwigshafen am Rhein', 'population': 163771, 'pais': 'Germany'}
# {'name': 'Burgos', 'population': 162802, 'pais': 'Spain'}
# {'name': 'Rubtsovsk', 'population': 162600, 'pais': 'Russian Federation'}
# {'name': 'Rzeszów', 'population': 162049, 'pais': 'Poland'}
# {'name': 'Bournemouth', 'population': 162000, 'pais': 'United Kingdom'}
# {'name': 'Kertš', 'population': 162000, 'pais': 'Ukraine'}
# {'name': 'Livorno', 'population': 161673, 'pais': 'Italy'}
# {'name': 'Aalborg', 'population': 161161, 'pais': 'Denmark'}
# {'name': 'Leverkusen', 'population': 160841, 'pais': 'Germany'}
# {'name': 'Toulon', 'population': 160639, 'pais': 'France'}
# {'name': 'Breda', 'population': 160398, 'pais': 'Netherlands'}
# {'name': 'Kovrov', 'population': 159900, 'pais': 'Russian Federation'}
# {'name': 'Ruda Slaska', 'population': 159665, 'pais': 'Poland'}
# {'name': 'Salamanca', 'population': 158720, 'pais': 'Spain'}
# {'name': 'Szeged', 'population': 158158, 'pais': 'Hungary'}
# {'name': 'Nahodka', 'population': 157700, 'pais': 'Russian Federation'}
# {'name': 'Pécs', 'population': 157332, 'pais': 'Hungary'}
# {'name': 'Ussurijsk', 'population': 157300, 'pais': 'Russian Federation'}
# {'name': 'Salavat', 'population': 156800, 'pais': 'Russian Federation'}
# {'name': 'Perugia', 'population': 156673, 'pais': 'Italy'}
# {'name': 'Brighton', 'population': 156124, 'pais': 'United Kingdom'}
# {'name': 'Peterborough', 'population': 156000, 'pais': 'United Kingdom'}
# {'name': 'Mytištši', 'population': 155700, 'pais': 'Russian Federation'}
# {'name': 'Priština', 'population': 155496, 'pais': 'Yugoslavia'}
# {'name': 'Foggia', 'population': 154891, 'pais': 'Italy'}
# {'name': 'Oldenburg', 'population': 154125, 'pais': 'Germany'}
# {'name': 'Apeldoorn', 'population': 153491, 'pais': 'Netherlands'}
# {'name': 'Balti', 'population': 153400, 'pais': 'Moldova'}
# {'name': 'Patras', 'population': 153344, 'pais': 'Greece'}
# {'name': 'Grenoble', 'population': 153317, 'pais': 'France'}
# {'name': 'Nijmegen', 'population': 152463, 'pais': 'Netherlands'}
# {'name': 'Angers', 'population': 151279, 'pais': 'France'}
# {'name': 'Borisov', 'population': 151000, 'pais': 'Belarus'}
# {'name': 'Blackpool', 'population': 151000, 'pais': 'United Kingdom'}
# {'name': 'Kolomna', 'population': 150700, 'pais': 'Russian Federation'}
# {'name': 'Trondheim', 'population': 150166, 'pais': 'Norway'}
# {'name': 'Dijon', 'population': 149867, 'pais': 'France'}
# {'name': 'Neuss', 'population': 149702, 'pais': 'Germany'}
# {'name': 'Baia Mare', 'population': 149665, 'pais': 'Romania'}
# {'name': 'Brest', 'population': 149634, 'pais': 'France'}
# {'name': 'Enschede', 'population': 149544, 'pais': 'Netherlands'}
# {'name': 'Nikopol', 'population': 149000, 'pais': 'Ukraine'}
# {'name': 'Haarlem', 'population': 148772, 'pais': 'Netherlands'}
# {'name': 'Buzau', 'population': 148372, 'pais': 'Romania'}
# {'name': 'Reading', 'population': 148000, 'pais': 'United Kingdom'}
# {'name': 'Stara Zagora', 'population': 147939, 'pais': 'Bulgaria'}
# {'name': 'Albacete', 'population': 147527, 'pais': 'Spain'}
# {'name': 'Kragujevac', 'population': 147305, 'pais': 'Yugoslavia'}
# {'name': 'Elektrostal', 'population': 147000, 'pais': 'Russian Federation'}
# {'name': 'Dundee', 'population': 146690, 'pais': 'United Kingdom'}
# {'name': 'Šiauliai', 'population': 146563, 'pais': 'Lithuania'}
# {'name': 'West Bromwich', 'population': 146386, 'pais': 'United Kingdom'}
# {'name': 'Le Mans', 'population': 146105, 'pais': 'France'}
# {'name': 'Oldbury/Smethwick (Warley)', 'population': 145542, 'pais': 'United Kingdom'}
# {'name': 'Getafe', 'population': 145371, 'pais': 'Spain'}
# {'name': 'Middlesbrough', 'population': 145000, 'pais': 'United Kingdom'}
# {'name': 'Rybnik', 'population': 144582, 'pais': 'Poland'}
# {'name': 'Salzburg', 'population': 144247, 'pais': 'Austria'}
# {'name': 'Oxford', 'population': 144000, 'pais': 'United Kingdom'}
# {'name': 'Huddersfield', 'population': 143726, 'pais': 'United Kingdom'}
# {'name': 'Reggio nell´ Emilia', 'population': 143664, 'pais': 'Italy'}
# {'name': 'Banja Luka', 'population': 143079, 'pais': 'Bosnia and Herzegovina'}
# {'name': 'Almere', 'population': 142465, 'pais': 'Netherlands'}
# {'name': 'Cádiz', 'population': 142449, 'pais': 'Spain'}
# {'name': 'Murom', 'population': 142400, 'pais': 'Russian Federation'}
# {'name': 'Salerno', 'population': 142055, 'pais': 'Italy'}
# {'name': 'Alcorcón', 'population': 142048, 'pais': 'Spain'}
# {'name': 'Kolpino', 'population': 141200, 'pais': 'Russian Federation'}
# {'name': 'Poole', 'population': 141000, 'pais': 'United Kingdom'}
# {'name': 'Norilsk', 'population': 140800, 'pais': 'Russian Federation'}
# {'name': 'Almetjevsk', 'population': 140700, 'pais': 'Russian Federation'}
# {'name': 'Huelva', 'population': 140583, 'pais': 'Spain'}
# {'name': 'Blackburn', 'population': 140000, 'pais': 'United Kingdom'}
# {'name': 'León', 'population': 139809, 'pais': 'Spain'}
# {'name': 'Castellón de la Plana [Castell', 'population': 139712, 'pais': 'Spain'}
# {'name': 'Heidelberg', 'population': 139672, 'pais': 'Germany'}
# {'name': 'Bolton', 'population': 139020, 'pais': 'United Kingdom'}
# {'name': 'Newport', 'population': 139000, 'pais': 'United Kingdom'}
# {'name': 'Ravenna', 'population': 138418, 'pais': 'Italy'}
# {'name': 'Novomoskovsk', 'population': 138100, 'pais': 'Russian Federation'}
# {'name': 'Arnhem', 'population': 138020, 'pais': 'Netherlands'}
# {'name': 'Darmstadt', 'population': 137776, 'pais': 'Germany'}
# {'name': 'Paderborn', 'population': 137647, 'pais': 'Germany'}
# {'name': 'Peristerion', 'population': 137288, 'pais': 'Greece'}
# {'name': 'Clermont-Ferrand', 'population': 137140, 'pais': 'France'}
# {'name': 'Dimitrovgrad', 'population': 137000, 'pais': 'Russian Federation'}
# {'name': 'Walbrzych', 'population': 136923, 'pais': 'Poland'}
# {'name': 'Badajoz', 'population': 136613, 'pais': 'Spain'}
# {'name': 'Pervouralsk', 'population': 136100, 'pais': 'Russian Federation'}
# {'name': 'Zaanstad', 'population': 135621, 'pais': 'Netherlands'}
# {'name': 'Amiens', 'population': 135501, 'pais': 'France'}
# {'name': 'Preston', 'population': 135000, 'pais': 'United Kingdom'}
# {'name': 'Podgorica', 'population': 135000, 'pais': 'Yugoslavia'}
# {'name': 'Aix-en-Provence', 'population': 134222, 'pais': 'France'}
# {'name': 'Limoges', 'population': 133968, 'pais': 'France'}
# {'name': 'Bruxelles [Brussel]', 'population': 133859, 'pais': 'Belgium'}
# {'name': 'Himki', 'population': 133700, 'pais': 'Russian Federation'}
# {'name': 'Panevezys', 'population': 133695, 'pais': 'Lithuania'}
# {'name': 'Nîmes', 'population': 133424, 'pais': 'France'}
# {'name': 'Tychy', 'population': 133178, 'pais': 'Poland'}
# {'name': 'Linköping', 'population': 133168, 'pais': 'Sweden'}
# {'name': 'Balašiha', 'population': 132900, 'pais': 'Russian Federation'}
# {'name': 'Tours', 'population': 132820, 'pais': 'France'}
# {'name': 'Stockport', 'population': 132813, 'pais': 'United Kingdom'}
# {'name': 'Nevinnomyssk', 'population': 132600, 'pais': 'Russian Federation'}
# {'name': 'Pjatigorsk', 'population': 132500, 'pais': 'Russian Federation'}
# {'name': 'Korolev', 'population': 132400, 'pais': 'Russian Federation'}
# {'name': 'Ferrara', 'population': 132127, 'pais': 'Italy'}
# {'name': 'Serpuhov', 'population': 132000, 'pais': 'Russian Federation'}
# {'name': 'Rimini', 'population': 131062, 'pais': 'Italy'}
# {'name': 'Dabrowa Górnicza', 'population': 131037, 'pais': 'Poland'}
# {'name': 'Plock', 'population': 131011, 'pais': 'Poland'}
# {'name': 'Satu Mare', 'population': 130059, 'pais': 'Romania'}
# {'name': 'Pinsk', 'population': 130000, 'pais': 'Belarus'}
# {'name': 'Berdjansk', 'population': 130000, 'pais': 'Ukraine'}
# {'name': 'Elblag', 'population': 129782, 'pais': 'Poland'}
# {'name': 'Opole', 'population': 129553, 'pais': 'Poland'}
# {'name': '´s-Hertogenbosch', 'population': 129170, 'pais': 'Netherlands'}
# {'name': 'Potsdam', 'population': 128983, 'pais': 'Germany'}
# {'name': 'Botosani', 'population': 128730, 'pais': 'Romania'}
# {'name': '[San Cristóbal de] la Laguna', 'population': 127945, 'pais': 'Spain'}
# {'name': 'Odintsovo', 'population': 127400, 'pais': 'Russian Federation'}
# {'name': 'Würzburg', 'population': 127350, 'pais': 'Germany'}
# {'name': 'Cork', 'population': 127187, 'pais': 'Ireland'}
# {'name': 'Györ', 'population': 127119, 'pais': 'Hungary'}
# {'name': 'Logroño', 'population': 127093, 'pais': 'Spain'}
# {'name': 'Pavlograd', 'population': 127000, 'pais': 'Ukraine'}
# {'name': 'Sjeverodonetsk', 'population': 127000, 'pais': 'Ukraine'}
# {'name': 'Slovjansk', 'population': 127000, 'pais': 'Ukraine'}
# {'name': 'Uzgorod', 'population': 127000, 'pais': 'Ukraine'}
# {'name': 'Västerås', 'population': 126328, 'pais': 'Sweden'}
# {'name': 'Syrakusa', 'population': 126282, 'pais': 'Italy'}
# {'name': 'Amersfoort', 'population': 126270, 'pais': 'Netherlands'}
# {'name': 'Gorzów Wielkopolski', 'population': 126019, 'pais': 'Poland'}
# {'name': 'Bender (Tîghina)', 'population': 125700, 'pais': 'Moldova'}
# {'name': 'Regensburg', 'population': 125236, 'pais': 'Germany'}
# {'name': 'Piatra Neamt', 'population': 125070, 'pais': 'Romania'}
# {'name': 'Recklinghausen', 'population': 125022, 'pais': 'Germany'}
# {'name': 'Orehovo-Zujevo', 'population': 124900, 'pais': 'Russian Federation'}
# {'name': 'Göttingen', 'population': 124775, 'pais': 'Germany'}
# {'name': 'Kamyšin', 'population': 124600, 'pais': 'Russian Federation'}
# {'name': 'Villeurbanne', 'population': 124215, 'pais': 'France'}
# {'name': 'Örebro', 'population': 124207, 'pais': 'Sweden'}
# {'name': 'Orša', 'population': 124000, 'pais': 'Belarus'}
# {'name': 'Norwich', 'population': 124000, 'pais': 'United Kingdom'}
# {'name': 'Metz', 'population': 123776, 'pais': 'France'}
# {'name': 'Novotšeboksarsk', 'population': 123400, 'pais': 'Russian Federation'}
# {'name': 'Wloclawek', 'population': 123373, 'pais': 'Poland'}
# {'name': 'Bremerhaven', 'population': 122735, 'pais': 'Germany'}
# {'name': 'Bern', 'population': 122700, 'pais': 'Switzerland'}
# {'name': 'Norrköping', 'population': 122199, 'pais': 'Sweden'}
# {'name': 'Amadora', 'population': 122106, 'pais': 'Portugal'}
# {'name': 'Maastricht', 'population': 122087, 'pais': 'Netherlands'}
# {'name': 'Wolfsburg', 'population': 121954, 'pais': 'Germany'}
# {'name': 'Pleven', 'population': 121952, 'pais': 'Bulgaria'}
# {'name': 'Chorzów', 'population': 121708, 'pais': 'Poland'}
# {'name': 'Tšerkessk', 'population': 121700, 'pais': 'Russian Federation'}
# {'name': 'Atšinsk', 'population': 121600, 'pais': 'Russian Federation'}
# {'name': 'Tarnów', 'population': 121494, 'pais': 'Poland'}
# {'name': 'Rotherham', 'population': 121380, 'pais': 'United Kingdom'}
# {'name': 'Bottrop', 'population': 121097, 'pais': 'Germany'}
# {'name': 'Cambridge', 'population': 121000, 'pais': 'United Kingdom'}
# {'name': 'Magadan', 'population': 121000, 'pais': 'Russian Federation'}
# {'name': 'Sassari', 'population': 120803, 'pais': 'Italy'}
# {'name': 'Santa Coloma de Gramenet', 'population': 120802, 'pais': 'Spain'}
# {'name': 'Oulu', 'population': 120753, 'pais': 'Finland'}
# {'name': 'Mitšurinsk', 'population': 120700, 'pais': 'Russian Federation'}
# {'name': 'Kislovodsk', 'population': 120400, 'pais': 'Russian Federation'}
# {'name': 'Remscheid', 'population': 120125, 'pais': 'Germany'}
# {'name': 'Dordrecht', 'population': 119811, 'pais': 'Netherlands'}
# {'name': 'Râmnicu Vâlcea', 'population': 119741, 'pais': 'Romania'}
# {'name': 'Heilbronn', 'population': 119526, 'pais': 'Germany'}
# {'name': 'Monza', 'population': 119516, 'pais': 'Italy'}
# {'name': 'Jelets', 'population': 119400, 'pais': 'Russian Federation'}
# {'name': 'Altševsk', 'population': 119000, 'pais': 'Ukraine'}
# {'name': 'Seversk', 'population': 118600, 'pais': 'Russian Federation'}
# {'name': 'Suceava', 'population': 118549, 'pais': 'Romania'}
# {'name': 'Zielona Góra', 'population': 118182, 'pais': 'Poland'}
# {'name': 'Drobeta-Turnu Severin', 'population': 117865, 'pais': 'Romania'}
# {'name': 'Bergamo', 'population': 117837, 'pais': 'Italy'}
# {'name': 'Helsingborg', 'population': 117737, 'pais': 'Sweden'}
# {'name': 'Besançon', 'population': 117733, 'pais': 'France'}
# {'name': 'Pforzheim', 'population': 117227, 'pais': 'Germany'}
# {'name': 'Noginsk', 'population': 117200, 'pais': 'Russian Federation'}
# {'name': 'Leiden', 'population': 117196, 'pais': 'Netherlands'}
# {'name': 'Jönköping', 'population': 117095, 'pais': 'Sweden'}
# {'name': 'Offenbach am Main', 'population': 116627, 'pais': 'Germany'}
# {'name': 'Velikije Luki', 'population': 116300, 'pais': 'Russian Federation'}
# {'name': 'Brugge', 'population': 116246, 'pais': 'Belgium'}
# {'name': 'Novokuibyševsk', 'population': 116200, 'pais': 'Russian Federation'}
# {'name': 'Herakleion', 'population': 116178, 'pais': 'Greece'}
# {'name': 'Ulm', 'population': 116103, 'pais': 'Germany'}
# {'name': 'Lysytšansk', 'population': 116000, 'pais': 'Ukraine'}
# {'name': 'Neftekamsk', 'population': 115700, 'pais': 'Russian Federation'}
# {'name': 'Pescara', 'population': 115698, 'pais': 'Italy'}
# {'name': 'Maribor', 'population': 115532, 'pais': 'Slovenia'}
# {'name': 'Daugavpils', 'population': 114829, 'pais': 'Latvia'}
# {'name': 'Ingolstadt', 'population': 114826, 'pais': 'Germany'}
# {'name': 'Gera', 'population': 114718, 'pais': 'Germany'}
# {'name': 'Lausanne', 'population': 114500, 'pais': 'Switzerland'}
# {'name': 'Kallithea', 'population': 114233, 'pais': 'Greece'}
# {'name': 'Latina', 'population': 114099, 'pais': 'Italy'}
# {'name': 'Ipswich', 'population': 114000, 'pais': 'United Kingdom'}
# {'name': 'Caen', 'population': 113987, 'pais': 'France'}
# {'name': 'Leninsk-Kuznetski', 'population': 113800, 'pais': 'Russian Federation'}
# {'name': 'Orléans', 'population': 113126, 'pais': 'France'}
# {'name': 'Larisa', 'population': 113090, 'pais': 'Greece'}
# {'name': 'Watford', 'population': 113080, 'pais': 'United Kingdom'}
# {'name': 'Tarragona', 'population': 113016, 'pais': 'Spain'}
# {'name': 'Salzgitter', 'population': 112934, 'pais': 'Germany'}
# {'name': 'Nyiregyháza', 'population': 112419, 'pais': 'Hungary'}
# {'name': 'Koszalin', 'population': 112375, 'pais': 'Poland'}
# {'name': 'Lleida (Lérida)', 'population': 112207, 'pais': 'Spain'}
# {'name': 'Slough', 'population': 112000, 'pais': 'United Kingdom'}
# {'name': 'Jevpatorija', 'population': 112000, 'pais': 'Ukraine'}
# {'name': 'Innsbruck', 'population': 111752, 'pais': 'Austria'}
# {'name': 'Oktjabrski', 'population': 111500, 'pais': 'Russian Federation'}
# {'name': 'Sergijev Posad', 'population': 111100, 'pais': 'Russian Federation'}
# {'name': 'Exeter', 'population': 111000, 'pais': 'United Kingdom'}
# {'name': 'Cottbus', 'population': 110894, 'pais': 'Germany'}
# {'name': 'Haarlemmermeer', 'population': 110722, 'pais': 'Netherlands'}
# {'name': 'Arzamas', 'population': 110700, 'pais': 'Russian Federation'}
# {'name': 'Mulhouse', 'population': 110359, 'pais': 'France'}
# {'name': 'Reutlingen', 'population': 110343, 'pais': 'Germany'}
# {'name': 'Zoetermeer', 'population': 110214, 'pais': 'Netherlands'}
# {'name': 'Mozyr', 'population': 110000, 'pais': 'Belarus'}
# {'name': 'Kiseljovsk', 'population': 110000, 'pais': 'Russian Federation'}
# {'name': 'Fürth', 'population': 109771, 'pais': 'Germany'}
# {'name': 'Vicenza', 'population': 109738, 'pais': 'Italy'}
# {'name': 'Novotroitsk', 'population': 109600, 'pais': 'Russian Federation'}
# {'name': 'Legnica', 'population': 109335, 'pais': 'Poland'}
# {'name': 'Jaén', 'population': 109247, 'pais': 'Spain'}
# {'name': 'Siegen', 'population': 109225, 'pais': 'Germany'}
# {'name': 'Reykjavík', 'population': 109184, 'pais': 'Iceland'}
# {'name': 'Ourense (Orense)', 'population': 109120, 'pais': 'Spain'}
# {'name': 'Kamjanets-Podilskyi', 'population': 109000, 'pais': 'Ukraine'}
# {'name': 'Stavanger', 'population': 108848, 'pais': 'Norway'}
# {'name': 'Obninsk', 'population': 108300, 'pais': 'Russian Federation'}
# {'name': 'Koblenz', 'population': 108003, 'pais': 'Germany'}
# {'name': 'Terni', 'population': 107770, 'pais': 'Italy'}
# {'name': 'Forlì', 'population': 107475, 'pais': 'Italy'}
# {'name': 'Kansk', 'population': 107400, 'pais': 'Russian Federation'}
# {'name': 'Gloucester', 'population': 107000, 'pais': 'United Kingdom'}
# {'name': 'Moers', 'population': 106837, 'pais': 'Germany'}
# {'name': 'Kalisz', 'population': 106641, 'pais': 'Poland'}
# {'name': 'Rouen', 'population': 106592, 'pais': 'France'}
# {'name': 'Boulogne-Billancourt', 'population': 106367, 'pais': 'France'}
# {'name': 'Glazov', 'population': 106300, 'pais': 'Russian Federation'}
# {'name': 'Saint Helens', 'population': 106293, 'pais': 'United Kingdom'}
# {'name': 'Bergisch Gladbach', 'population': 106150, 'pais': 'Germany'}
# {'name': 'Sutton Coldfield', 'population': 106001, 'pais': 'United Kingdom'}
# {'name': 'Novopolotsk', 'population': 106000, 'pais': 'Belarus'}
# {'name': 'Cheltenham', 'population': 106000, 'pais': 'United Kingdom'}
# {'name': 'Solikamsk', 'population': 106000, 'pais': 'Russian Federation'}
# {'name': 'Emmen', 'population': 105853, 'pais': 'Netherlands'}
# {'name': 'Zwolle', 'population': 105819, 'pais': 'Netherlands'}
# {'name': 'Sarapul', 'population': 105700, 'pais': 'Russian Federation'}
# {'name': 'Schaerbeek', 'population': 105692, 'pais': 'Belgium'}
# {'name': 'Kecskemét', 'population': 105606, 'pais': 'Hungary'}
# {'name': 'Sliven', 'population': 105530, 'pais': 'Bulgaria'}
# {'name': 'Namur', 'population': 105419, 'pais': 'Belgium'}
# {'name': 'Ust-Ilimsk', 'population': 105200, 'pais': 'Russian Federation'}
# {'name': 'Székesfehérvár', 'population': 105119, 'pais': 'Hungary'}
# {'name': 'Perpignan', 'population': 105115, 'pais': 'France'}
# {'name': 'Jenakijeve', 'population': 105000, 'pais': 'Ukraine'}
# {'name': 'Trento', 'population': 104906, 'pais': 'Italy'}
# {'name': 'Štšolkovo', 'population': 104900, 'pais': 'Russian Federation'}
# {'name': 'Osijek', 'population': 104761, 'pais': 'Croatia'}
# {'name': 'Umeå', 'population': 104512, 'pais': 'Sweden'}
# {'name': 'York', 'population': 104425, 'pais': 'United Kingdom'}
# {'name': 'Mezduretšensk', 'population': 104400, 'pais': 'Russian Federation'}
# {'name': 'Zwickau', 'population': 104146, 'pais': 'Germany'}
# {'name': 'Mataró', 'population': 104095, 'pais': 'Spain'}
# {'name': 'Hildesheim', 'population': 104013, 'pais': 'Germany'}
# {'name': 'Oldham', 'population': 103931, 'pais': 'United Kingdom'}
# {'name': 'Nancy', 'population': 103605, 'pais': 'France'}
# {'name': 'Usolje-Sibirskoje', 'population': 103500, 'pais': 'Russian Federation'}
# {'name': 'Witten', 'population': 103384, 'pais': 'Germany'}
# {'name': 'Elista', 'population': 103300, 'pais': 'Russian Federation'}
# {'name': 'Algeciras', 'population': 103106, 'pais': 'Spain'}
# {'name': 'Schwerin', 'population': 102878, 'pais': 'Germany'}
# {'name': 'Olomouc', 'population': 102702, 'pais': 'Czech Republic'}
# {'name': 'Grudziadz', 'population': 102434, 'pais': 'Poland'}
# {'name': 'Slupsk', 'population': 102370, 'pais': 'Poland'}
# {'name': 'Jastrzebie-Zdrój', 'population': 102294, 'pais': 'Poland'}
# {'name': 'Novara', 'population': 102037, 'pais': 'Italy'}
# {'name': 'Novošahtinsk', 'population': 101900, 'pais': 'Russian Federation'}
# {'name': 'Votkinsk', 'population': 101700, 'pais': 'Russian Federation'}
# {'name': 'Ede', 'population': 101574, 'pais': 'Netherlands'}
# {'name': 'Bærum', 'population': 101340, 'pais': 'Norway'}
# {'name': 'Tartu', 'population': 101246, 'pais': 'Estonia'}
# {'name': 'Marbella', 'population': 101144, 'pais': 'Spain'}
# {'name': 'Kyzyl', 'population': 101100, 'pais': 'Russian Federation'}
# {'name': 'Lida', 'population': 101000, 'pais': 'Belarus'}
# {'name': 'Soligorsk', 'population': 101000, 'pais': 'Belarus'}
# {'name': 'Krasnyi Lutš', 'population': 101000, 'pais': 'Ukraine'}
# {'name': 'Stahanov', 'population': 101000, 'pais': 'Ukraine'}
# {'name': 'Basildon', 'population': 100924, 'pais': 'United Kingdom'}
# {'name': 'Erlangen', 'population': 100750, 'pais': 'Germany'}
# {'name': 'Serov', 'population': 100400, 'pais': 'Russian Federation'}
# {'name': 'Dobric', 'population': 100399, 'pais': 'Bulgaria'}
# {'name': 'Subotica', 'population': 100386, 'pais': 'Yugoslavia'}
# {'name': 'Zelenodolsk', 'population': 100200, 'pais': 'Russian Federation'}
# {'name': 'Zeleznodoroznyi', 'population': 100100, 'pais': 'Russian Federation'}
# {'name': 'Kaiserslautern', 'population': 100025, 'pais': 'Germany'}
# {'name': 'Worthing', 'population': 100000, 'pais': 'United Kingdom'}
# {'name': 'Kinešma', 'population': 100000, 'pais': 'Russian Federation'}
# {'name': 'Trier', 'population': 99891, 'pais': 'Germany'}
# {'name': 'Jena', 'population': 99779, 'pais': 'Germany'}
# {'name': 'Iserlohn', 'population': 99474, 'pais': 'Germany'}
# {'name': 'Liberec', 'population': 99155, 'pais': 'Czech Republic'}
# {'name': 'Oleksandrija', 'population': 99000, 'pais': 'Ukraine'}
# {'name': 'Târgoviste', 'population': 98980, 'pais': 'Romania'}
# {'name': 'Focsani', 'population': 98979, 'pais': 'Romania'}
# {'name': 'Lund', 'population': 98948, 'pais': 'Sweden'}
# {'name': 'Târgu Jiu', 'population': 98524, 'pais': 'Romania'}
# {'name': 'Piacenza', 'population': 98384, 'pais': 'Italy'}
# {'name': 'Ancona', 'population': 98329, 'pais': 'Italy'}
# {'name': 'Barakaldo', 'population': 98212, 'pais': 'Spain'}
# {'name': 'Lecce', 'population': 98208, 'pais': 'Italy'}
# {'name': 'Kuznetsk', 'population': 98200, 'pais': 'Russian Federation'}
# {'name': 'Ceské Budejovice', 'population': 98186, 'pais': 'Czech Republic'}
# {'name': 'Hradec Králové', 'population': 98080, 'pais': 'Czech Republic'}
# {'name': 'Uhta', 'population': 98000, 'pais': 'Russian Federation'}
# {'name': 'Jaworzno', 'population': 97929, 'pais': 'Poland'}
# {'name': 'Jessentuki', 'population': 97900, 'pais': 'Russian Federation'}
# {'name': 'Tobolsk', 'population': 97600, 'pais': 'Russian Federation'}
# {'name': 'Chelmsford', 'population': 97451, 'pais': 'United Kingdom'}
# {'name': 'Neftejugansk', 'population': 97400, 'pais': 'Russian Federation'}
# {'name': 'Bataisk', 'population': 97300, 'pais': 'Russian Federation'}
# {'name': 'Nojabrsk', 'population': 97300, 'pais': 'Russian Federation'}
# {'name': 'Bolzano', 'population': 97232, 'pais': 'Italy'}
# {'name': 'Balašov', 'population': 97100, 'pais': 'Russian Federation'}
# {'name': 'Molodetšno', 'population': 97000, 'pais': 'Belarus'}
# {'name': 'Crawley', 'population': 97000, 'pais': 'United Kingdom'}
# {'name': 'Roubaix', 'population': 96984, 'pais': 'France'}
# {'name': 'Lahti', 'population': 96921, 'pais': 'Finland'}
# {'name': 'Zeleznogorsk', 'population': 96900, 'pais': 'Russian Federation'}
# {'name': 'Borås', 'population': 96883, 'pais': 'Sweden'}
# {'name': 'Catanzaro', 'population': 96700, 'pais': 'Italy'}
# {'name': 'Zukovski', 'population': 96500, 'pais': 'Russian Federation'}
# {'name': 'Tulcea', 'population': 96278, 'pais': 'Romania'}
# {'name': 'Coímbra', 'population': 96100, 'pais': 'Portugal'}
# {'name': 'Anzero-Sudzensk', 'population': 96100, 'pais': 'Russian Federation'}
# {'name': 'Colchester', 'population': 96063, 'pais': 'United Kingdom'}
# {'name': 'Zenica', 'population': 96027, 'pais': 'Bosnia and Herzegovina'}
# {'name': 'Konotop', 'population': 96000, 'pais': 'Ukraine'}
# {'name': 'La Spezia', 'population': 95504, 'pais': 'Italy'}
# {'name': 'Ústí nad Labem', 'population': 95491, 'pais': 'Czech Republic'}
# {'name': 'Delft', 'population': 95268, 'pais': 'Netherlands'}
# {'name': 'Heerlen', 'population': 95052, 'pais': 'Netherlands'}
# {'name': 'Gütersloh', 'population': 95028, 'pais': 'Germany'}
# {'name': 'Worcester', 'population': 95000, 'pais': 'United Kingdom'}
# {'name': 'Kostjantynivka', 'population': 95000, 'pais': 'Ukraine'}
# {'name': 'Udine', 'population': 94932, 'pais': 'Italy'}
# {'name': 'Šumen', 'population': 94686, 'pais': 'Bulgaria'}
# {'name': 'Dos Hermanas', 'population': 94591, 'pais': 'Spain'}
# {'name': 'Solihull', 'population': 94531, 'pais': 'United Kingdom'}
# {'name': 'Torre del Greco', 'population': 94505, 'pais': 'Italy'}
# {'name': 'Andria', 'population': 94443, 'pais': 'Italy'}
# {'name': 'Rochdale', 'population': 94313, 'pais': 'United Kingdom'}
# {'name': 'Bugulma', 'population': 94100, 'pais': 'Russian Federation'}
# {'name': 'Zeleznogorsk', 'population': 94000, 'pais': 'Russian Federation'}
# {'name': 'Prešov', 'population': 93977, 'pais': 'Slovakia'}
# {'name': 'Resita', 'population': 93976, 'pais': 'Romania'}
# {'name': 'Argenteuil', 'population': 93961, 'pais': 'France'}
# {'name': 'Jelenia Góra', 'population': 93901, 'pais': 'Poland'}
# {'name': 'Santiago de Compostela', 'population': 93745, 'pais': 'Spain'}
# {'name': 'Marl', 'population': 93735, 'pais': 'Germany'}
# {'name': 'Tourcoing', 'population': 93540, 'pais': 'France'}
# {'name': 'Brindisi', 'population': 93454, 'pais': 'Italy'}
# {'name': 'Novouralsk', 'population': 93300, 'pais': 'Russian Federation'}
# {'name': 'Giugliano in Campania', 'population': 93286, 'pais': 'Italy'}
# {'name': 'Sundsvall', 'population': 93126, 'pais': 'Sweden'}
# {'name': 'Birkenhead', 'population': 93087, 'pais': 'United Kingdom'}
# {'name': 'Puškin', 'population': 92900, 'pais': 'Russian Federation'}
# {'name': 'Alkmaar', 'population': 92713, 'pais': 'Netherlands'}
# {'name': 'Vorkuta', 'population': 92600, 'pais': 'Russian Federation'}
# {'name': 'Pisa', 'population': 92379, 'pais': 'Italy'}
# {'name': 'Prizren', 'population': 92303, 'pais': 'Yugoslavia'}
# {'name': 'Derbent', 'population': 92300, 'pais': 'Russian Federation'}
# {'name': 'Torrejón de Ardoz', 'population': 92262, 'pais': 'Spain'}
# {'name': 'Lünen', 'population': 92044, 'pais': 'Germany'}
# {'name': 'Gillingham', 'population': 92000, 'pais': 'United Kingdom'}
# {'name': 'Hartlepool', 'population': 92000, 'pais': 'United Kingdom'}
# {'name': 'Woking/Byfleet', 'population': 92000, 'pais': 'United Kingdom'}
# {'name': 'Barletta', 'population': 91904, 'pais': 'Italy'}
# {'name': 'Arezzo', 'population': 91729, 'pais': 'Italy'}
# {'name': 'Kirovo-Tšepetsk', 'population': 91600, 'pais': 'Russian Federation'}
# {'name': 'Pardubice', 'population': 91309, 'pais': 'Czech Republic'}
# {'name': 'Klagenfurt', 'population': 91141, 'pais': 'Austria'}
# {'name': 'Düren', 'population': 91092, 'pais': 'Germany'}
# {'name': 'Halifax', 'population': 91069, 'pais': 'United Kingdom'}
# {'name': 'Krasnogorsk', 'population': 91000, 'pais': 'Russian Federation'}
# {'name': 'Southport', 'population': 90959, 'pais': 'United Kingdom'}
# {'name': 'Ratingen', 'population': 90951, 'pais': 'Germany'}
# {'name': 'Mons', 'population': 90935, 'pais': 'Belgium'}
# {'name': 'Maidstone', 'population': 90878, 'pais': 'United Kingdom'}
# {'name': 'Gävle', 'population': 90742, 'pais': 'Sweden'}
# {'name': 'Montreuil', 'population': 90674, 'pais': 'France'}
# {'name': 'Braga', 'population': 90535, 'pais': 'Portugal'}
# {'name': 'Frederiksberg', 'population': 90327, 'pais': 'Denmark'}
# {'name': 'Alessandria', 'population': 90289, 'pais': 'Italy'}
# {'name': 'Eastbourne', 'population': 90000, 'pais': 'United Kingdom'}
# {'name': 'Klin', 'population': 90000, 'pais': 'Russian Federation'}
# {'name': 'Tšaikovski', 'population': 90000, 'pais': 'Russian Federation'}
# {'name': 'Berdytšiv', 'population': 90000, 'pais': 'Ukraine'}
# {'name': 'Izmajil', 'population': 90000, 'pais': 'Ukraine'}
# {'name': 'Šostka', 'population': 90000, 'pais': 'Ukraine'}
# {'name': 'Uman', 'population': 90000, 'pais': 'Ukraine'}
# {'name': 'Velbert', 'population': 89881, 'pais': 'Germany'}
# {'name': 'Cesena', 'population': 89852, 'pais': 'Italy'}
# {'name': 'Novyi Urengoi', 'population': 89800, 'pais': 'Russian Federation'}
# {'name': 'Esslingen am Neckar', 'population': 89667, 'pais': 'Germany'}
# {'name': 'Liepaja', 'population': 89439, 'pais': 'Latvia'}
# {'name': 'Grimsby', 'population': 89000, 'pais': 'United Kingdom'}
# {'name': 'Brovary', 'population': 89000, 'pais': 'Ukraine'}
# {'name': 'Mukatševe', 'population': 89000, 'pais': 'Ukraine'}
# {'name': 'Pesaro', 'population': 88987, 'pais': 'Italy'}
# {'name': 'Luxembourg [Luxemburg/Lëtzebuerg]', 'population': 80700, 'pais': 'Luxembourg'}
# {'name': 'Saint Helier', 'population': 27523, 'pais': 'United Kingdom'}
# {'name': 'Gibraltar', 'population': 27025, 'pais': 'Gibraltar'}
# {'name': 'Douglas', 'population': 23487, 'pais': 'United Kingdom'}
# {'name': 'Birkirkara', 'population': 21445, 'pais': 'Malta'}
# {'name': 'Andorra la Vella', 'population': 21189, 'pais': 'Andorra'}
# {'name': 'Tórshavn', 'population': 14542, 'pais': 'Faroe Islands'}
# {'name': 'Monte-Carlo', 'population': 13154, 'pais': 'Monaco'}
# {'name': 'Valletta', 'population': 7073, 'pais': 'Malta'}
# {'name': 'Schaan', 'population': 5346, 'pais': 'Liechtenstein'}
# {'name': 'Vaduz', 'population': 5043, 'pais': 'Liechtenstein'}
# {'name': 'Serravalle', 'population': 4802, 'pais': 'San Marino'}
# {'name': 'San Marino', 'population': 2294, 'pais': 'San Marino'}
# {'name': 'Longyearbyen', 'population': 1438, 'pais': 'Svalbard and Jan Mayen'}
# {'name': 'Monaco-Ville', 'population': 1234, 'pais': 'Monaco'}
# {'name': 'Città del Vaticano', 'population': 455, 'pais': 'Holy See (Vatican City State)'}
#
# ================================================================================
#   EJERCICIO 5: Actualizar Población de China
# ================================================================================
# ✓ Registros afectados: 0
# ================================================================================
#
#
# ================================================================================
#   Verificación: Población de China Actualizada
# ================================================================================
# {'code': 'CHN', 'name': 'China', 'population': 1500000000}
#
# ================================================================================
#   Idiomas Oficiales en Sudamérica
# ================================================================================
# {'language': 'Spanish', 'cantidad_paises': 9}
# {'language': 'Aimará', 'cantidad_paises': 2}
# {'language': 'Ketšua', 'cantidad_paises': 2}
# {'language': 'English', 'cantidad_paises': 1}
# {'language': 'Guaraní', 'cantidad_paises': 1}
# {'language': 'Portuguese', 'cantidad_paises': 1}
# ================================================================================
#   Esperanza de Vida > 75 años
# ================================================================================
# Total de países encontrados: 62
# País                           | Esperanza de Vida
# --------------------------------------------------
# Andorra                        |       83.5 años
# Macao                          |       81.6 años
# San Marino                     |       81.1 años
# Japan                          |       80.7 años
# Singapore                      |       80.1 años
# Australia                      |       79.8 años
# Switzerland                    |       79.6 años
# Sweden                         |       79.6 años
# Hong Kong                      |       79.5 años
# Canada                         |       79.4 años
# ...
# ================================================================================
#   Regiones con Esperanza de Vida Bajo Promedio (ODS 3)
# ================================================================================
# {'continent': 'Africa', 'paises_afectados': 48, 'esperanza_media': Decimal('48.93')}
# {'continent': 'Asia', 'paises_afectados': 20, 'esperanza_media': Decimal('59.08')}
# {'continent': 'Oceania', 'paises_afectados': 6, 'esperanza_media': Decimal('62.68')}
# {'continent': 'South America', 'paises_afectados': 3, 'esperanza_media': Decimal('63.53')}
# {'continent': 'North America', 'paises_afectados': 3, 'esperanza_media': Decimal('59.97')}
# {'continent': 'Europe', 'paises_afectados': 2, 'esperanza_media': Decimal('65.25')}
#
# ================================================================================
#   Países con Mayor Riesgo por Megaciudades (ODS 11)
# ================================================================================
# País                           | Ciudad Principal          | % Población
# ---------------------------------------------------------------------------
# Singapore                      | Singapore                 |     112.64%
# Gibraltar                      | Gibraltar                 |     108.10%
# Macao                          | Macao                     |      92.49%
# Pitcairn                       | Adamstown                 |      84.00%
# Cocos (Keeling) Islands        | Bantam                    |      83.83%
# ================================================================================
#   Países sin Idioma Oficial (Alta Población)
# ================================================================================
# {'pais': 'Nigeria', 'population': 111506000, 'total_idiomas': 10}
# {'pais': 'Ethiopia', 'population': 62565000, 'total_idiomas': 7}
# {'pais': 'Congo, The Democratic Republic of the', 'population': 51654000, 'total_idiomas': 10}
# {'pais': 'Kenya', 'population': 30080000, 'total_idiomas': 10}
# {'pais': 'Uganda', 'population': 21778000, 'total_idiomas': 10}
# ================================================================================
#   ✓ Todas las consultas ejecutadas correctamente
# ================================================================================
